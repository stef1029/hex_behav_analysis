# %% [markdown]
# # Behaviour plotting April 2024:
#
# This notebook is intended as the main plotting area of the March Behaviour cohort.
#
# ## To do:
# To show that mice have learned the task well, I would like to plot overall performance, and performance in visual and audio trials.
#
# I would also like to plot the performance over time in all phases.
#
# I would also like to plot the radial performance in the end phase, a plot showing a total performance, visual performance and audio performance all on the same graph with different coloured lines.
#
# Then, once I’ve done the cue times test, I’d like to plot the performance radially for each of the cue time bins, with different coloured lines representing the performance.
#
# There is likely to also be a learning curve for each of the cue times, so it would also be good to do a plot of total performance over time for each of the cue times. Radial plot would likely not have enough trials to show this very clearly.
#
#
# I also need to calculate actual turn angle for each trial, so that mistakes can be included. This will allow me to bin the movements into visual, audio and mistake categories to see the performance.
#
# I also need to make a good figure demonstrating the behaviour at this point.

# %% [markdown]
# ## Description of the cohort/ behaviour:
# ### Mice:
# 8 mice, males, wild type, unmodified.
# ### Goal of the training:
# To establish the learning parameters and performance of wild type mice in the full behaviour.
# ### Behaviour:
# Mice were trained with the end goal of achieving one perticular task:
# Mice self initiate each trial by standing on a small platform/ puck in the centre of the red hex arena.
# This platform is a set of scales which detects the weight of the mouse to automatically determine the presence of the mouse.
# At this point, a cue is given, and mice must decide which port to go to to receive some milk reward.
# The cues can either be visual or audio based.
# In visual trials, a green LED flashes on one of the 6 walls, indicating to the mouse that that port will give reward.
# In audio trials, an overhead speaker beeps, indicating that mice must go to port 1 to receive their reward.
# The duration of each LED and audio cue is identical.
# If mice go to the correct port, they receive a drop of milk, and can immediately go back to the platform to self initiate a new trial.
# If mice go to the wrong port, an error signal is given and mice receive nothing. The error signal consists of a 10 second spotlight brightness increase, and mice are not able to initiate a new trial within this 10 seconds, acting as a timeout.
# If mice do not go to a port, the trial times out after 10 seconds, after which a new cue is given if the mouse activates the scales.
# Mice then continue to perform trials for the duration of the session, usually about 1hr long. In this time mice are able to perform up to 400 trials.
# ### Training:
# Mice have their behaviour shaped to achieve this end task. This is done by moving through different phases of the behaviour over the course of a week, starting out with simple versions of the task and progressively making it harder. In this cohort, progression onto the next phase was judged manually. Phase numbers/ names are a bit messy.
# - **Phase 2:**
# *Aim*: To teach the mouse to go to the platform to receive reward.
# *Task*: When mice put their full weight on the platform, a drop of milk is immediately given at port 1, which the mouse can then go and find. Once the mouse has taken the reward (activated the sensor at port 1), they are able to get another drop by going back to the platform.
# *Performance evaluation*: Mice are moved on to the next phase when they are consistently going back and forth between the platform and the reward port, demonstrating that they understand that visiting the platform causes reward release at a specific port.
# *Early behaviour*: Mice will explore the arena, investigating ports to see if there's milk, as usually they are able to find residue in the arena. Mice are encouraged onto the platform by a drop of milk being put in the centre by the experimenter, so after the mice find this they are more likely to revisit the platform and cause a port 1 activation. Once they are visiting the platform, it takes a bit for them to realise the reward is always at port 1, meaning they will oftern visit other ports first in a semi-random manner.
# - **Phase 3:**
# *Aim*: To teach mice to only visit port 1, and also to introduce the LED and that the reward is only given when the mouse nose-pokes.
# *Task*: Mice initiate a trial by standing on the platform, at which point the LED at port 1 comes on. If the mice visit port 1 then they receive the reward, however if they visit another port first then an error signal is given and they receive no reward that trial. The LED turns off when the mouse touches a port.
# *Performance evaluation*: Mice move on to the next phase when they are consistently getting the reward and not getting error signals at a high rate.
# - **Phase 4:**
# *Aim*: To teach mice to wait for a short time on the platform before the cue is given. Pause time = 1s.
# *Task*: This is the same as phase 3 except that mice must pause for a short time on the platform before the cue is given. This is to encourage waiting for the cue to be given so that mice don't impulsively walk off the platform before seeing where the cue is.
# *Performance evaluation*: Mice are moved on when they can consistently get the reward and are not getting errors. They should also be showing a clear pause on the platform before moving off.
# - **Phase 'test':**
# *Aim*: To examine the strategy that the mice are using to get to port 1.
# *Task*: 5 trials are given with the LED at port 1 and then 10 trials are given with the LED at port 3. IF the mice go to either port 1 or 3 they can receive reward.
# *Performance evaluation*: The aim is to evaluate if the mice are using the LED or the external landmarks in the arena to navigate to port 1. If mice switch to going to port 3 once the cue is given there, then they are following the LED. If they continue to go to port 1, then they are following the landmarks in the arena.
# - **Phase 5:**
# *Aim*: Introduction of port 3 consistently.
# *Task*: Mice are given the cue at port 3, and are allowed to make mistakes without receiving an error signal.
# *Performance evaluation*: This phase is only brief, and is moved on from when mice are showing that they can go to port 3 consistenly and aren't just checking randomly.
# - **Phase 7:**
# *Aim*: To teach mice to consistently follow the LED to get the reward.
# *Task*: The cue and correct port are switched randomly between port 1 and port 3. Mice are given error signal for incorrect port touches.
# *Performance evalutation*: Mice are moved on when they are consistenly getting the task correct and following the LED location.
# - **Phase 9:**
# *Aim*: To teach the mice that the reward is potentially given at all 6 ports.
# *Task*: Cue randomly switched between ports 1 to 6.
# - **Phase 4b:**
# *Aim*: Teaching the mice audio trials.
# *Task*: The cue is randomly switched between a visual cue at port 1 and an audio cue. Mice must go to port 1 to receive reward in both cases.
# - **Phase 4c:**
# *Aim*: Continued audio trial education.
# *Task*: Mice are only given audio trials and must go to port 1 to receive reward. Error signals are given for incorrect port touches.
# - **Phase 9b:**
# *Aim*: To teach mice a full version of the mixed cue task.
# *Task*: Visual cues are given at all ports, and audio cues are given on random trials. If the visual cue is given, micem ust go to the corresponding port, if an audio cue is given, mice must go to port 1. The proportion of audio:visual trials is set by the experimenter. I used either 1:1 or 2 parts audio 3 parts visual on sessions.
# - **Phase 9c:**
# *Aim*: To teach mice the short cue task.
# *Task*: Same are 9b but the cue time is set to only give the cue for a short time, <1sec. Visual and audio cue time are identical. Same thing about proportion as 9b, I used 1:1 audio:visual on the end day of behaviour.
#
# ### Cue time experiment:
# Mice in this cohort went through an experiment where the performance on the task was evaluated for different visual cue durations. When the cue time is short and the cue is behind the mouse, they are unable to see if and so cannot tell which port to go to. However, for my future optogenetics experiments, it is important for me to target the inhibition time to specific times in a trial, for example specifically during cue presentation or perhaps just after. I therefore performed an experiment to evaluate the radial performance of mice with different cue lengths, to find a good middle point where mice are performing movements towards cues they are seeing instantly, instead of hunting around for the cue, but without having cues so short that performance drops even for ports in front of mice.
# Cue times used: 1000ms, 500ms, 300ms, 100ms. (needs to be checked from the data as didn't note this down.)

# %% [markdown]
# ## Import modules:

# %%
# Imports:

# %matplotlib inline
from matplotlib import pyplot as plt
from Session_nwb import Session
from pathlib import Path
from Cohort_folder import Cohort_folder
import json
import numpy as np
import os
from datetime import datetime

try:
    behaviour_data = Path(os.getenv("behaviour_data"))
except TypeError:
    print('"behaviour_data" environment variable does not exist.')
    try:
        behaviour_data = Path(r"/lmb/home/srogers/DATA")
    except TypeError:
        raise Exception("Tried using hex path but not available.")

July_cohort_directory = behaviour_data / 'July_portable'
March_cohort_directory = behaviour_data / 'March_portable'

fig_output = Path(os.getenv("fig_output"))

cohort = Cohort_folder(March_cohort_directory, multi = True, portable_data = True)
cohort_info = cohort.cohort
phases = cohort.phases()

# Import plotting functions:
import importlib
import PP_plot_performance
# Out:
# Loading cohort info...

# %%
from pathlib import Path
import os
fig_output = Path(os.getenv("fig_output"))

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Base performance plotting:**
# The aim of this plot is to show radial performance in different phases of the behaviour.
# I would like to plot the radial performance overall, in the visual trials only and in audio trials only.
# These can either be seperate plots or overlayed.
# Session groups to plot:
# - 1: Last day session full: (9c, 300ms cue with audio) - 6 mice (28th)
# - Not to plot here -- 1b: Last day 9c without audio. Since mice were getting 1:1 audio:visual, there was a chance they were just guessing when they didn't see the visual cue and not necessarily listening for the audio. I wanted to see if the mice would continue to check port 1 as much if the audio cue wasn't there, or if they would randomly pick on ones where they couldn't see.
# - 2: 16th/17th March 9b sessions - 8 mice on Sat, 6 mice on Sun, although rig broke Sun so may need to discard some.
# - 3: Individual 9c sessions in cue time experiment + phase 9 sessions on Sat 23rd. - 1 day phase 9 (23rd), 4 days with short cues (24th - 27th).
#
# Plan:
# Get all trials from sessions. Bin trials into cue presentation angle. Create 3 arrays, one of overall performance in each angle, one in visual and one in audio. Plot using radial plot function. Also plot as 2 line graphs.

# %%
# View phases dict:
phases

# %% [markdown]
# ### View base performance for last day full behaviour:

# %%
# Group 1 session list: (Last day 9c sessions - full task)
sessions = []

for session in phases['9c']:
    date = session[:6]
    
    if date == '240328':
        sessions.append(session)
        # print(session)
        
# sort list:
sessions.sort()

# On this day, I did one 9c with audio then one without to see their performance change, so need to filter this set.

# sessions_to_exclude = [
#  '240328_143110',
#  '240328_143231']
    
# non_audio_sessions = [
#  '240328_163535',
#  '240328_163559',
#  '240328_182501',
#  '240328_182532']

# audio_9c_sessions = [
#  '240328_143915',
#  '240328_143947',
#  '240328_155006',
#  '240328_155038',
#  '240328_174624',
#  '240328_174653']

sessions_to_exclude = [
 '240328_143110',
 '240328_143231']
    
non_audio_sessions = [
 '240328_163535',
 '240328_163559',
 '240328_182501',
 '240328_182532']

audio_9c_sessions = [
 '240328_143915_wtjx287-5c',
 '240328_143947_wtjx287-5b',
 '240328_155006_wtjx287-5d',
 '240328_155038_wtjx306-1a',
 '240328_174624_wtjx306-1b',
 '240328_174653_wtjx298-2a']

# %%
# Load sessions in:

audio_9c_sessions = [Session(cohort.get_session(session)) for session in audio_9c_sessions]
# Out:
# Loading session 240328_143915_wtjx287-5c...
# Loading session 240328_143947_wtjx287-5b...
# Loading session 240328_155006_wtjx287-5d...
# Loading session 240328_155038_wtjx306-1a...
# Loading session 240328_174624_wtjx306-1b...
# Loading session 240328_174653_wtjx298-2a...

# %%
importlib.reload(PP_plot_performance)
fig_output = Path(os.getenv("fig_output"))
from datetime import datetime
plot_out_folder = "allo-ego session plots March 24"
date_time = datetime.now().strftime("%Y%m%d_%H%M%S")
new_output = fig_output / plot_out_folder / date_time

# PP_plot_performance.plot_performance_by_angle(audio_9c_sessions, 
#                                               title = 'Full task (300ms cue time)', 
#                                               bin_mode = 'manual', 
#                                               trials_per_bin=100, 
#                                               plot_mode='radial', 
#                                               cue_modes=['all_trials'],
#                                               error_bars='SEM',
#                                               output_path=fig_output)

PP_plot_performance.plot_performance_by_angle(audio_9c_sessions, 
                                              title = 'Audio vs visual - line plot', 
                                              bin_mode = 'manual', 
                                              trials_per_bin=100, 
                                              plot_mode='linear_comparison', 
                                              cue_modes=['visual_trials', 'audio_trials'],
                                              error_bars='SEM',
                                              output_path=new_output,
                                              plot_individual_mice=False,
                                              exclusion_mice=[])

PP_plot_performance.plot_performance_by_angle(audio_9c_sessions, 
                                              title = 'Audio vs visual - radial plot', 
                                              bin_mode = 'manual', 
                                              trials_per_bin=100, 
                                              plot_mode='radial', 
                                              cue_modes=['visual_trials', 'audio_trials'],
                                              error_bars='SEM',
                                              output_path=new_output,
                                              plot_individual_mice=False,
                                              exclusion_mice=[])

PP_plot_performance.plot_performance_by_angle(audio_9c_sessions, 
                                              title = 'Audio only - individual mice', 
                                              bin_mode = 'manual', 
                                              trials_per_bin=100, 
                                              plot_mode='radial', 
                                              cue_modes=['audio_trials'],
                                              error_bars='SEM',
                                              output_path=new_output,
                                              plot_individual_mice=True,
                                              exclusion_mice=[])

PP_plot_performance.plot_performance_by_angle(audio_9c_sessions, 
                                              title = 'Audio only', 
                                              bin_mode = 'manual', 
                                              trials_per_bin=100, 
                                              plot_mode='radial', 
                                              cue_modes=['audio_trials'],
                                              error_bars='SEM',
                                              output_path=new_output,
                                              plot_individual_mice=False,
                                              exclusion_mice=[])

PP_plot_performance.plot_performance_by_angle(audio_9c_sessions, 
                                              title = 'Audio only - excluding mice - individual', 
                                              bin_mode = 'manual', 
                                              trials_per_bin=100, 
                                              plot_mode='radial', 
                                              cue_modes=['audio_trials'],
                                              error_bars='SEM',
                                              output_path=new_output,
                                              plot_individual_mice=True,
                                              exclusion_mice=['wtjx298-2a', 'wtjx306-1b', 'wtjx287-5d'])

PP_plot_performance.plot_performance_by_angle(audio_9c_sessions, 
                                              title = 'Audio only - excluding mice - average', 
                                              bin_mode = 'manual', 
                                              trials_per_bin=100, 
                                              plot_mode='radial', 
                                              cue_modes=['audio_trials'],
                                              error_bars='SEM',
                                              output_path=new_output,
                                              plot_individual_mice=False,
                                              exclusion_mice=['wtjx298-2a', 'wtjx306-1b', 'wtjx287-5d'])

# PP_plot_performance.plot_performance_by_angle(audio_9c_sessions, 
#                                               title = 'Full task (300ms cue time) (audio only)', 
#                                               bin_mode = 'manual', 
#                                               trials_per_bin=100, 
#                                               plot_mode='radial', 
#                                               cue_modes=['audio_trials'],
#                                               error_bars='SEM')
# Out:
# Saving plot as SVG to: 'C:\Data\Figure output\allo-ego session plots March 24\20240916_145458\20240916_145458_angular_performance_line_visual_trials_audio_trials.svg'
# Saving plot as PNG to: 'C:\Data\Figure output\allo-ego session plots March 24\20240916_145458\20240916_145458_angular_performance_line_visual_trials_audio_trials.png'
# Saving plot as SVG to: 'C:\Data\Figure output\allo-ego session plots March 24\20240916_145458\20240916_145458_angular_performance_line_visual_trials_audio_trials_0.svg'
# Saving plot as PNG to: 'C:\Data\Figure output\allo-ego session plots March 24\20240916_145458\20240916_145458_angular_performance_line_visual_trials_audio_trials_0.png'
# Saving plot as SVG to: 'C:\Data\Figure output\allo-ego session plots March 24\20240916_145458\20240916_145459_angular_performance_line_audio_trials.svg'
# Saving plot as PNG to: 'C:\Data\Figure output\allo-ego session plots March 24\20240916_145458\20240916_145459_angular_performance_line_audio_trials.png'
# ...

# %% [markdown]
# ### View performance on phase 9b with unlimited cue length and mixed audio and visual trials:

# %%
# Group 2 sessions: 
# (16th/17th March 9b sessions - 8 mice on Sat, 6 mice on Sun, although rig broke Sun so may need to discard some.)

sessions = []

for session in phases['9b']:
    date = session[:6]
    
    if date == '240316' or date == '240317':
        sessions.append(session)
        
sessions.sort()
    
all_9b_sessions = sessions

first_day_9b = [session for session in phases['9b'] if session[:6] == '240316']


sessions = first_day_9b

print("Sessions in use:")
for session in sessions:
    date = session[:6]
    print(date, cohort.get_session(session, concise = True))

# %%
# Load session objects:
first_day_9b_Sessions = [Session(cohort.get_session(session)) for session in first_day_9b]

# %%
# Plot performance on both, visual and audio trials:

PP_plot_performance.plot_performance_by_angle(first_day_9b_Sessions, 
                                              title = 'Full task (unlimited cue time)', 
                                              bin_mode = 'manual', 
                                              trials_per_bin=100, 
                                              plot_mode='radial', 
                                              cue_mode='both',
                                              error_bars='SEM')

PP_plot_performance.plot_performance_by_angle(first_day_9b_Sessions, 
                                              title = 'Full task (unlimited cue time) (visual only)', 
                                              bin_mode = 'manual', 
                                              trials_per_bin=100, 
                                              plot_mode='radial', 
                                              cue_mode='visual',
                                              error_bars='SEM')

PP_plot_performance.plot_performance_by_angle(first_day_9b_Sessions, 
                                              title = 'Full task (unlimited cue time) (audio only)', 
                                              bin_mode = 'manual', 
                                              trials_per_bin=100, 
                                              plot_mode='radial', 
                                              cue_mode='audio',
                                              error_bars='SEM')

# %% [markdown]
# ### View performance across different cue presentation times:

# %%
# Group 3: 
# Individual 9c sessions in cue time experiment + phase 9 sessions on Sat 23rd. 
#  - 1 day phase 9 (23rd), 4 days with short cues (24th - 27th)

cue_group_unlimited = [Session(cohort.get_session(session)) for session in phases['9'] if session[:6] == '240323']

cue_group_1000 = [Session(cohort.get_session(session)) for session in phases['9c'] if session[:6] == '240324']

cue_group_500 = [session for session in phases['9c'] if session[:6] == '240325']
exclusion_500 = ['240325_183546', '240325_183459']                                  # these session have the timestamp error (caused by recording stopping early (SRC 26/6/24))
cue_group_500 = [Session(cohort.get_session(session)) for session in cue_group_500 if session not in exclusion_500]

cue_group_300 = [Session(cohort.get_session(session)) for session in phases['9c'] if session[:6] == '240326']

cue_group_100 = [session for session in phases['9c'] if session[:6] == '240327']
exclusion_100 = ['240327_160220', '240327_160142']
cue_group_100 = [Session(cohort.get_session(session)) for session in cue_group_100 if session not in exclusion_100]

sessions = cue_group_100

# session_count = 0
# for session in sessions:
#     print(session, cohort.get_session(session, concise=True))
#     print(f"Session {session_count} of {len(sessions)}")
# Out:
# Loading session...
# phase: '9'
# Session loaded.
# Loading session...
# phase: '9'
# Session loaded.
# Loading session...
# phase: '9'
# Session loaded.
# Loading session...
# phase: '9'
# Session loaded.
# Loading session...
# phase: '9'
# Session loaded.
# Loading session...
# phase: '9'
# Session loaded.
# Loading session...
# phase: '9'
# Session loaded.
# Loading session...
# phase: '9'
# Session loaded.
# Loading session...
# phase: '9c'
# Session loaded.
# Loading session...
# phase: '9c'
# Session loaded.
# Loading session...
# phase: '9c'
# Session loaded.
# Loading session...
# phase: '9c'
# Session loaded.
# Loading session...
# phase: '9c'
# Session loaded.
# Loading session...
# phase: '9c'
# Session loaded.
# Loading session...
# phase: '9c'
# Session loaded.
# Loading session...
# phase: '9c'
# Session loaded.
# Loading session...
# phase: '9c'
# Session loaded.
# Loading session...
# phase: '9c'
# Session loaded.
# Loading session...
# phase: '9c'
# Session loaded.
# ...

# %%
# Load sessions:

Sessions = []

for session in sessions:
    sess = Session(cohort.get_session(session))
    Sessions.append(sess)
    print(sess.session_ID)

# %%
# plot performance:
PP_plot_performance.plot_performance_by_angle(cue_group_unlimited, 
                                              title = 'Angular performance (unlimited cue)', 
                                              bin_mode = 'manual', 
                                              trials_per_bin=100, 
                                              plot_mode='bar_split_overlay', 
                                              cue_mode='both',
                                              error_bars='SEM')

PP_plot_performance.plot_performance_by_angle(cue_group_1000, 
                                              title = 'Angular performance (1000ms cue)', 
                                              bin_mode = 'manual', 
                                              trials_per_bin=100, 
                                              plot_mode='bar_split_overlay', 
                                              cue_mode='both',
                                              error_bars='SEM')

PP_plot_performance.plot_performance_by_angle(cue_group_500, 
                                              title = 'Angular performance (500ms cue)', 
                                              bin_mode = 'manual', 
                                              trials_per_bin=100, 
                                              plot_mode='bar_split_overlay', 
                                              cue_mode='both',
                                              error_bars='SEM')

PP_plot_performance.plot_performance_by_angle(cue_group_300, 
                                              title = 'Angular performance (300ms cue)', 
                                              bin_mode = 'manual', 
                                              trials_per_bin=100, 
                                              plot_mode='bar_split_overlay', 
                                              cue_mode='both',
                                              error_bars='SEM')

PP_plot_performance.plot_performance_by_angle(cue_group_100, 
                                              title = 'Angular performance (100ms cue)', 
                                              bin_mode = 'manual', 
                                              trials_per_bin=100, 
                                              plot_mode='bar_split_overlay', 
                                              cue_mode='both',
                                              error_bars='SEM')

# PP_plot_performance.plot_performance_by_angle(cohort, Sessions, bin_mode = 'manual', trials_per_bin=100, plot_mode='radial', cue_mode='visual')
# PP_plot_performance.plot_performance_by_angle(cohort, Sessions, bin_mode = 'manual', trials_per_bin=100, plot_mode='radial', cue_mode='audio')
# Out:
# /cephfs2/srogers/New_analysis_pipeline/Scripts/PP_plot_performance.py:182: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "o-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.errorbar(bin_numeric, left_performance, yerr=left_errors, fmt='o-', color='royalblue', ecolor='lightsteelblue', elinewidth=3, capsize=0, linestyle='-', linewidth=2, label=left_title)
# /cephfs2/srogers/New_analysis_pipeline/Scripts/PP_plot_performance.py:183: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "o-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.errorbar(bin_numeric, right_performance, yerr=right_errors, fmt='o-', color='darkorange', ecolor='moccasin', elinewidth=3, capsize=0, linestyle='-', linewidth=2, label=right_title)
# ...

# %% [markdown]
# ## Cue time experiment:

# %%
import PP_plot_cue_time_experiment

# %%
sessions = [cue_group_unlimited, cue_group_1000, cue_group_500, cue_group_300, cue_group_100]
cue_times = ['Unlimited', '1000ms', '500ms', '300ms', '100ms']

importlib.reload(PP_plot_cue_time_experiment)

PP_plot_cue_time_experiment.plot_performance_by_angle(sessions,
                                                      cue_times,
                                                      title = '',
                                                      bin_mode = 'manual',
                                                      trials_per_bin=100,
                                                      plot_mode='radial',
                                                      error_bars='SEM')

# %%
# Cue time experiment group: 
# Using loaded in session from block above:

# sessions = [cue_group_unlimited, cue_group_1000, cue_group_500, cue_group_300, cue_group_100]

# sessions = [cue_group_300, cue_group_100]
# cue_times = ['300ms', '100ms']

# 500, 300, 100:
sessions = [cue_group_500, cue_group_300, cue_group_100]
cue_times = ['500ms', '300ms', '100ms']

# sessions = [cue_group_100]
# cue_times = ['100ms']

importlib.reload(PP_plot_cue_time_experiment)

PP_plot_cue_time_experiment.plot_performance_by_angle(sessions,
                                                      cue_times,
                                                      title = '',
                                                      bin_mode = 'manual',
                                                      trials_per_bin=100,
                                                      plot_mode='radial',
                                                      error_bars='SEM',
                                                      x_label_gap = 30)

# %% [markdown]
# ### Same again but all on one side:

# %%
# sessions = [cue_group_unlimited, cue_group_1000, cue_group_500, cue_group_300, cue_group_100]
# cue_times = ['Unlimited', '1000ms', '500ms', '300ms', '100ms']

sessions = [cue_group_300, cue_group_100]
cue_times = ['300ms', '100ms']

importlib.reload(PP_plot_cue_time_experiment)

PP_plot_cue_time_experiment.plot_performance_by_angle(sessions,
                                                      cue_times,
                                                      title = '',
                                                      bin_mode = 'manual',
                                                      num_bins = 12,
                                                      plot_mode='radial_abs',
                                                      error_bars='SEM',
                                                      x_label_gap = 15)

# %% [markdown]
# ### Final session 9c port 1 test. See section on 1b in 'Base performance plotting'
# Goal here is to evaluate the choices in port that mice make when they don't get a visible visual cue. I would like to establish whether there is a difference in port choice between the first and second 9c session.
# Mice are meant to learn to only go to port 1 if there is an audio cue, however it may also be the case that they just guess and default to port 1 when they don't see a cue. If this was the case, then there would be a large bias in the port that mice are touching when they touch the wrong port. This should be visible in 9c audio, but I suspect that in 9c non-audio immediately afterwards, the mice are still overly checking port 1. To evaluate this, I want to get the numbers on the number of times each port is chosen as the wrong port. I suspect that port 1 would be much higher than others. For each angle bin, for unsuccessful trials, I would also like to get the probability that port 1 is chosen. It would be interesting to see if there is a bias to port one for trials where the mouse got the cue behind him.

# %% [markdown]
# ## Plot learning:
#
# My goal here is to plot the performance over time for all phases on each day.

# %%
phase_2_sessions = [session for session in phases['2'] if session[:6] == '240311']

phase_3_sessions = [session for session in phases['3'] if session[:6] == '240312']

phase_4_sessions = [session for session in phases['4'] if session[:6] == '240313']

phase_7_exclusion = ['']
phase_7_sessions = [session for session in phases['7'] if session[:6] == '240314' and session not in phase_7_exclusion]

# %% [markdown]
# ## Phase 'test' experiment:
#
# Plot results of 'test' phase:

# %%
test_phase_sessions = [Session(cohort.get_session(session)) for session in phases['test'] if session[:6] == '240314']

# for session in test_phase_sessions:
#     date = session[:6]
#     print(date, cohort.get_session(session, concise=True))

# %%
import PP_plot_phase_test_experiment

# %%
importlib.reload(PP_plot_phase_test_experiment)

# %%
PP_plot_phase_test_experiment.plot_test(test_phase_sessions)

# %% [markdown]
# # Investigating incorrect port touches
#
# The goal and idea here is to further investigate the activty of mice in short cue tasks.
# My is it that mice appear to not be able to go to correct ports even if they are in their peripheral vision when the light flashes?
#
# ## Current theories:
# **The mice can't see it:**
# Unlikely since I can probably find work showing they have a wide enough peripheral vision.
#
# **Mice need to see it with both eyes to make a turn there:**
# This theory is that the mice must be able to lock onto the target with both eyes to be able to make the movement there.
# To test this, I would like to see whether at the moment the LED goes off, mouse head position predicts the likelihood of the mouse getting the reward (Are the mice looking at the ones they can get?)
#
# Plot: For successful trials, plot mod head angle from correct port at time of LED off. For unsuccessful trials, do the same. Do this for each angle bin, creating a line plot with two lines, one for success and one for failure. In angle bins with c.50:50 success/ failure, I expect that successful trials would have a bias towards the 0 degree area.
#
# **When the LED goes off, mice just continue in whatever direction they were going to already:**
# This is almost similar to how the mice might be remembering where they are going after the LED turns off. If the mouse is heading towards a port at the time the LED goes off, is that the one they go for? In this case, the vector the mouse is travelling along at the time of cue off would predict the port touched.
#
# Plot: For all trials, get port touched and calculate a direction of travel of the mouse at cue offset. If you then follow this line, it will come close to a port at some point. What proportion of the time is this port the port touched?
#
# **Mice just lose track of the led after it goes off but the movement while the led was on was the same:**
#
# **The mice are just fast enough to reach the ports within the time it's on when it's in front:**
# To see this, I need to plot the number of trials where the mouse beat the LED offset time. The margin of this may correlate to the angle and success rate, and if so,
#
# **The mice go to a port nearby because they couldn't see exaclty where it was:**
# If I look at incorrect port touches, are they ones nearby the correct one? For incorrect trials, what is the port distance that they chose, for different angles of cue presentation?
#
# **They think it's an audio trial and go to the landmarked port instead:**
# For mixed cue sessions, perhaps their strategy is that if they don't see the light, just go to the landmarked port. Therefore, for unsuccessful trials, there is a higher chance of the port number being 1, while the others should be equal.

# %% [markdown]
# Ok so it seems that I'm getting the result I expected, but now I need to check that this isn't just an obvious byproduct of when the port is right in front of the mice. It would be good to also inclue the original cue presentatio angle in some way.
# It does seem that gin, even if the led is in the mouse's periphery that it can't seem to get it right.

# %%
import PP_cue_offset_heading

# %%
importlib.reload(PP_cue_offset_heading)

# %%
importlib.reload(PP_cue_offset_heading)

PP_cue_offset_heading.mouse_heading_cue_offset(cue_group_unlimited, 
                                               title='Unlimited cue',
                                               plot_type='radial',
                                               angle_mode='normal')

PP_cue_offset_heading.mouse_heading_cue_offset(cue_group_1000, 
                                               title='1000ms cue',
                                               plot_type='radial',
                                               angle_mode='normal')

PP_cue_offset_heading.mouse_heading_cue_offset(cue_group_500, 
                                               title='500ms cue',
                                               plot_type='radial',
                                               angle_mode='normal')
# PP_cue_offset_heading.mouse_heading_cue_offset(cue_group_500, 
#                                                title='500ms cue',
#                                                start_angle='60',
#                                                angle_mode='normal')

PP_cue_offset_heading.mouse_heading_cue_offset(cue_group_300, 
                                               title='300ms cue',
                                               plot_type='radial',
                                               angle_mode='normal')

PP_cue_offset_heading.mouse_heading_cue_offset(cue_group_100, 
                                               title='100ms cue',
                                               plot_type='radial',
                                               angle_mode='normal')

PP_cue_offset_heading.mouse_heading_cue_offset(cue_group_100, 
                                               title='100ms cue',
                                               plot_type='radial',
                                               angle_mode='normal',
                                               offset=0.2)

# %% [markdown]
# Plot change in angle between start and end of cue:

# %%
importlib.reload(PP_cue_offset_heading)

PP_cue_offset_heading.mouse_heading_cue_offset(cue_group_unlimited, 
                                               title='Unlimited cue',
                                               plot_type='radial',
                                               angle_mode='delta')

PP_cue_offset_heading.mouse_heading_cue_offset(cue_group_1000, 
                                               title='1000ms cue',
                                               plot_type='radial',
                                               angle_mode='delta')

PP_cue_offset_heading.mouse_heading_cue_offset(cue_group_500, 
                                               title='500ms cue',
                                               plot_type='radial',
                                               angle_mode='delta')

PP_cue_offset_heading.mouse_heading_cue_offset(cue_group_300, 
                                               title='300ms cue',
                                               plot_type='radial',
                                               angle_mode='delta')

PP_cue_offset_heading.mouse_heading_cue_offset(cue_group_100, 
                                               title='100ms cue',
                                               plot_type='radial',
                                               angle_mode='delta')

PP_cue_offset_heading.mouse_heading_cue_offset(cue_group_100, 
                                               title='100ms cue',
                                               plot_type='radial',
                                               angle_mode='delta',
                                               offset = 0.2)

# %% [markdown]
# ### Plotting trial times in similar way:
#
# Goal - For each trial, get the time it happened, and then bin the trials in a tight angle space, maybe 5 degree bins. Then, on two axes, scatter plot the points, with the colour of the points representing progression through the session.

# %%
import PP_cue_offset_heading_trial_times

# %%
importlib.reload(PP_cue_offset_heading_trial_times)

PP_cue_offset_heading_trial_times.mouse_heading_cue_offset(cue_group_unlimited,
                                                           title='Unlimited cue',
                                                           failure_mode='split')

PP_cue_offset_heading_trial_times.mouse_heading_cue_offset(cue_group_1000,
                                                              title='1000ms cue',
                                                           failure_mode='split')

PP_cue_offset_heading_trial_times.mouse_heading_cue_offset(cue_group_500,
                                                                title='500ms cue',
                                                           failure_mode='split')
# PP_cue_offset_heading_trial_times.mouse_heading_cue_offset(cue_group_500,
#                                                                 title='500ms cue',
#                                                                 start_angle='60')

PP_cue_offset_heading_trial_times.mouse_heading_cue_offset(cue_group_300,
                                                                title='300ms cue',
                                                           failure_mode='split')

PP_cue_offset_heading_trial_times.mouse_heading_cue_offset(cue_group_100,
                                                                title='100ms cue',
                                                           failure_mode='split')

# %% [markdown]
# Ok, this seems to show that the unsuccessful trials are evenly ditributed across the session, meaning that the error is not due to motivation.
# Now my question is what are the mice doing during these error trials. My suspicion is that they are still doing something, they aren't just sitting there, so where are they going?
# I'm also interested in how long it takes for the mice to get to the ports. Since the ones in front of them are quicker to get to, is the threshold of failure due to travel time? If I plot the time between the reward going off and the sensor touch for each angle of presentation, I would expect it to increase as it goes behind then, but is this in line with the threshold of success too?

# %% [markdown]
# ### Plotting time from cue off to reward taken:
#
# For each reward presentation bin, get the average time between cue off and reward taken:

# %%
import PP_plot_time_from_cue_off_to_sensor

# %%
importlib.reload(PP_plot_time_from_cue_off_to_sensor)

PP_plot_time_from_cue_off_to_sensor.plot_performance_by_angle(cue_group_500,
                                                                title='Unlimited cue',
                                                                time_to_plot='total_time',
                                                                trial_type='overlay',
                                                                cue_duration = 'unlimited')

PP_plot_time_from_cue_off_to_sensor.plot_performance_by_angle(cue_group_1000,
                                                                title='1000ms cue',
                                                                time_to_plot='total_time',
                                                                trial_type='overlay',
                                                                cue_duration = 1)

PP_plot_time_from_cue_off_to_sensor.plot_performance_by_angle(cue_group_500,
                                                                title='500ms cue',
                                                                time_to_plot='total_time',
                                                                trial_type='overlay',
                                                                cue_duration = 0.5)

PP_plot_time_from_cue_off_to_sensor.plot_performance_by_angle(cue_group_300,
                                                                title='300ms cue',
                                                                time_to_plot='total_time',
                                                                trial_type='overlay',
                                                                cue_duration = 0.3,)

PP_plot_time_from_cue_off_to_sensor.plot_performance_by_angle(cue_group_100,
                                                                title='100ms cue',
                                                                time_to_plot='total_time',
                                                                trial_type='overlay',
                                                                cue_duration = 0.1)

# %% [markdown]
# So, with the total_time graphs, you can see that mice that are reacting faster to go to a port than the unsuccessful ones where I assume thy are guessing a bit.

# %% [markdown]
# I would like to see a comparison of times to get to a port for all the different cue times to see if they are a different speed or not, and then I would also like to see a proper distribution of the times plotted for each angle of presentation.

# %% [markdown]
# Ok but right now I would like to investigate the ports the mice go to when they are unsuccessful. I need to make sure I'm not ignoring trial timeouots in the analysis here though.
#
# Firstly, do mice still go to a reward port even if they are getting it wrong?
# Find trial timeouts and plot this on the performance plots to show the proportion of those too. Arguably this should also be included in the general performance plots, need to make sure those are there.
#
# Then, relative to the correct port, which port do the mice choose? if port 3 is correct, is there a bias towards 2 and 4? For successful trials, this will show a plot where they always choose to go in the direction of the cue presentation. On unsuccessful trials, I can also plot the end angle/ port angle? Basically I want to plot head angle at reward received time, but I can do this just by looking at what sensor was touched. I could also choose to plot the head angle at cue offset grpahs as radial graphs I now realise, which might make the results of that more obvious.

# %% [markdown]
# It would also be good to evaluate DLC coordds likelihoods at these timepoints, such as cue presentation time, offset and sensor activation.

# %%
import PP_error_port_selection

# %%
importlib.reload(PP_error_port_selection)

PP_error_port_selection.error_trial_port_selection(cue_group_unlimited, 
                                               title='Unlimited cue',
                                               plot_type='radial')

PP_error_port_selection.error_trial_port_selection(cue_group_1000,
                                                  title='1000ms cue',
                                                  plot_type='radial')

PP_error_port_selection.error_trial_port_selection(cue_group_500,
                                                    title='500ms cue',
                                                    plot_type='radial')

PP_error_port_selection.error_trial_port_selection(cue_group_300,
                                                    title='300ms cue',
                                                    plot_type='radial')

PP_error_port_selection.error_trial_port_selection(cue_group_100,
                                                    title='100ms cue',
                                                    plot_type='radial')

# %% [markdown]
# Ok so it seems that the verdict so far is that when the cue is given at a port in the mouse's periphery it has a lower likelihood of accurately going to that port, and that they seem to get distracted by other ports along the way. However, this isn't necessarily as uninteresting as it might seem, since these errors are still the result of mice not turning their heads to see the lights.

# %% [markdown]
# Ok, but what if there is a difference in how the mice are starting the trials that means they miss it that can be seen in the behavioural data? Are there any more environmental factors that are causing this behaviour?
#
# Find the speed at which the mice are moving their heads at the time of cue initiation, for successful and unsuccessful trials.
# For each cue presentation angle, get speeds, sort into bins and plot as a distribution. Do for success and fail and see if the distributions are similar.

# %%
import PP_head_speed_evaluation

# %%
importlib.reload(PP_head_speed_evaluation)

PP_head_speed_evaluation.evaluate_head_speed(cue_group_unlimited,
                                                title='Unlimited cue')

PP_head_speed_evaluation.evaluate_head_speed(cue_group_1000,
                                                title='1000ms cue')

PP_head_speed_evaluation.evaluate_head_speed(cue_group_500,
                                                title='500ms cue')

PP_head_speed_evaluation.evaluate_head_speed(cue_group_300,
                                                title='300ms cue')

PP_head_speed_evaluation.evaluate_head_speed(cue_group_100,
                                                title='100ms cue')

# %% [markdown]
# I now want to look at the movements that the mice are making to get to the ports in successful and error trials. I will interpolate the dlc data to normalise the coordinates across all trials to fit a set number of frames, and then average the coordinates for each mouse to create an averge movement.

# %%
import PP_average_movements

# %%
importlib.reload(PP_average_movements)

PP_average_movements.plot_average_movements(cue_group_unlimited,
                                            title='Unlimited cue')

PP_average_movements.plot_average_movements(cue_group_1000,
                                            title='1000ms cue')

PP_average_movements.plot_average_movements(cue_group_500,
                                            title='500ms cue')

PP_average_movements.plot_average_movements(cue_group_300,
                                            title='300ms cue')

PP_average_movements.plot_average_movements(cue_group_100,
                                            title='100ms cue')

# %% [markdown]
# Building on the average movement plot, what does this movement look like in other metrics?
# Plot the speed and acceleration of these average movements:

# %%
import PP_average_movement_analysis

# %%
importlib.reload(PP_average_movement_analysis)

PP_average_movement_analysis.plot_average_movements(cue_group_unlimited,
                                            title='Unlimited cue')

PP_average_movement_analysis.plot_average_movements(cue_group_1000,
                                            title='1000ms cue')

PP_average_movement_analysis.plot_average_movements(cue_group_500,
                                            title='500ms cue')

PP_average_movement_analysis.plot_average_movements(cue_group_300,
                                            title='300ms cue')

PP_average_movement_analysis.plot_average_movements(cue_group_100,
                                            title='100ms cue')

# %% [markdown]
# For trials in cue bins, plot the speed over time of the mouse, and also plot the acceleration over time. Do I see a peak in the acceleration at a particular point that can be extracted.
#
# Filter trials to be longer than 400ms (average time to get reward directly in front is 500ms). Then cut the data to only include the first 400ms data (12 frames).
# I'll do the first 400ms for now, as this will still be interesting for the trials where the mice do move off quickly vs the ones they don't, say the 60 degree 300ms trials.

# %%
import PP_mouse_speed_evaluation as PP_mouse_speed_evaluation

# %%
importlib.reload(PP_mouse_speed_evaluation)

PP_mouse_speed_evaluation.evaluate_speed(cue_group_unlimited,
                                               title='Unlimited cue')

PP_mouse_speed_evaluation.evaluate_speed(cue_group_1000,
                                                  title='1000ms cue')

PP_mouse_speed_evaluation.evaluate_speed(cue_group_500,
                                                title='500ms cue')

PP_mouse_speed_evaluation.evaluate_speed(cue_group_300,
                                                title='300ms cue')

PP_mouse_speed_evaluation.evaluate_speed(cue_group_100,
                                                title='100ms cue')

# %% [markdown]
# I would now like to plot the head angle over time as the mice approach the platform.

# %%
import PP_mouse_head_angle_over_time

# %%
importlib.reload(PP_mouse_head_angle_over_time)

PP_mouse_head_angle_over_time.plot_average_movements(cue_group_unlimited,
                                               title='Unlimited cue')

PP_mouse_head_angle_over_time.plot_average_movements(cue_group_1000,
                                                    title='1000ms cue')

PP_mouse_head_angle_over_time.plot_average_movements(cue_group_500,
                                                    title='500ms cue')

PP_mouse_head_angle_over_time.plot_average_movements(cue_group_300,
                                                    title='300ms cue')

PP_mouse_head_angle_over_time.plot_average_movements(cue_group_100,
                                                    title='100ms cue')

# %% [markdown]
# Ok so I think in conclusion i can say that:
# Mouse spatial attention:
# Mice have a bias of attention for cues in the front +-60 degrees of vision, about half of their visual field.
# I believe this because Their performance is close to 100% when cues are within this range, but drops rapidly outside this range. This seems to line up with the nasal temporal hemispheres of the mouse retina. (show plot of performances)
# The performance in the 300ms+ trials should be discounted because mice are able to turn their heads to face the LED in the time it is on, while in 100ms trials they are not. (show head angle at cue offset plots)
# The drop in performance is not due to boring reasons (show plots of head speed at cue presentation, times of trials through session plots)
#
# Analysis of mouse turning movements:
# This base behaviour is a model of mouse orienting movements towards goals.
# Averaging successful trial movements so far has shown a clear average movement that the mice make, allowing high n access to these movements.
#
# Proof of concept of a mixed cue behaviour:
# The point of this is to control for the cue mode during stimulation and recording experiments. It also me to access the difference in computation when the mouse is following the location of the cue vs when it is instructed to navigate to a learned landmark.
# Importantly, it works, and shows a clear difference in performance to cued ports behind the mice.

# %% [markdown]
# Marco's ideas:
#
# Reanalyse performance and time taken to ports based only on port 1, to compare the movements to exactly the same port and see if theres a difference based on audio vs visual movements.
#
# Experiment: Tone goes on as soon as mouse on platform, and there's then either a 500 or 1000ms delay. Then, the LED comes on, either at 50% brightness or full brightness, for 100ms. The idea here is that if its attention based on the brightness of the led, then you will see an increase in peripheral performance, but if it's the expectation of reward at a certain time, then the perfomance might increase in the 1000ms delay ones vs 500ms.
#
# Further analysis that needs doing:
# Get video frames to visually check mouse head orientation and light direction (draw angles and estimated light position).
# Head movement analysis for angles behind mice. Are the mice actually static before they start moving or is this an artefact of averaging?
# In error trials, can I get a more accurate representation of what the mice are doing - is there a bias towards light presentation side or not?
# Summary plots of big plots - For plots with all bins visible, I need to get some sort of summary of the trends that I see in these plots so that the point of them can be displayed as one graph.

# %% [markdown]
# ### Checking the port angles visually:
#
# The goal here is to make a function that takes a session and for each angle bin makes an album of photos of the position the mouse is in at cue presentation, the estimated position of the LED, and a drawing of the angle calculation that the system does. This will be the first main check that the mice are actually able to see the cues and that the ear or head isn't in the way.
#
# This script will need to sort the trials as normal, and then find the frame numbers to grab. For each trial it will then draw the information on top of the frame and save it to a particular folder for that angle bin, with the trial number and angle of presentation as the title of the image.
# Only takes one session.

# %%
import PP_cue_angle_visual_check

# %%
importlib.reload(PP_cue_angle_visual_check)

session = cue_group_100[0]

PP_cue_angle_visual_check.get_images(session)
