# %% [markdown]
# # Behaviour plotting April 2024:
#
# This notebook is intended as the main plotting area of the March Behaviour cohort.
#
# ## To do:
# To show that mice have learned the task well, I would like to plot overall performance, and performance in visual and audio trials.
#
# I would also like to plot the performance over time in all phases.
#
# I would also like to plot the radial performance in the end phase, a plot showing a total performance, visual performance and audio performance all on the same graph with different coloured lines.
#
# Then, once I’ve done the cue times test, I’d like to plot the performance radially for each of the cue time bins, with different coloured lines representing the performance.
#
# There is likely to also be a learning curve for each of the cue times, so it would also be good to do a plot of total performance over time for each of the cue times. Radial plot would likely not have enough trials to show this very clearly.
#
#
# I also need to calculate actual turn angle for each trial, so that mistakes can be included. This will allow me to bin the movements into visual, audio and mistake categories to see the performance.
#
# I also need to make a good figure demonstrating the behaviour at this point.

# %% [markdown]
# ## Description of the cohort/ behaviour:
# ### Mice:
# 8 mice, males, wild type, unmodified.
# ### Goal of the training:
# To establish the learning parameters and performance of wild type mice in the full behaviour.
# ### Behaviour:
# Mice were trained with the end goal of achieving one perticular task:
# Mice self initiate each trial by standing on a small platform/ puck in the centre of the red hex arena.
# This platform is a set of scales which detects the weight of the mouse to automatically determine the presence of the mouse.
# At this point, a cue is given, and mice must decide which port to go to to receive some milk reward.
# The cues can either be visual or audio based.
# In visual trials, a green LED flashes on one of the 6 walls, indicating to the mouse that that port will give reward.
# In audio trials, an overhead speaker beeps, indicating that mice must go to port 1 to receive their reward.
# The duration of each LED and audio cue is identical.
# If mice go to the correct port, they receive a drop of milk, and can immediately go back to the platform to self initiate a new trial.
# If mice go to the wrong port, an error signal is given and mice receive nothing. The error signal consists of a 10 second spotlight brightness increase, and mice are not able to initiate a new trial within this 10 seconds, acting as a timeout.
# If mice do not go to a port, the trial times out after 10 seconds, after which a new cue is given if the mouse activates the scales.
# Mice then continue to perform trials for the duration of the session, usually about 1hr long. In this time mice are able to perform up to 400 trials.
# ### Training:
# Mice have their behaviour shaped to achieve this end task. This is done by moving through different phases of the behaviour over the course of a week, starting out with simple versions of the task and progressively making it harder. In this cohort, progression onto the next phase was judged manually. Phase numbers/ names are a bit messy.
# - **Phase 2:**
# *Aim*: To teach the mouse to go to the platform to receive reward.
# *Task*: When mice put their full weight on the platform, a drop of milk is immediately given at port 1, which the mouse can then go and find. Once the mouse has taken the reward (activated the sensor at port 1), they are able to get another drop by going back to the platform.
# *Performance evaluation*: Mice are moved on to the next phase when they are consistently going back and forth between the platform and the reward port, demonstrating that they understand that visiting the platform causes reward release at a specific port.
# *Early behaviour*: Mice will explore the arena, investigating ports to see if there's milk, as usually they are able to find residue in the arena. Mice are encouraged onto the platform by a drop of milk being put in the centre by the experimenter, so after the mice find this they are more likely to revisit the platform and cause a port 1 activation. Once they are visiting the platform, it takes a bit for them to realise the reward is always at port 1, meaning they will oftern visit other ports first in a semi-random manner.
# - **Phase 3:**
# *Aim*: To teach mice to only visit port 1, and also to introduce the LED and that the reward is only given when the mouse nose-pokes.
# *Task*: Mice initiate a trial by standing on the platform, at which point the LED at port 1 comes on. If the mice visit port 1 then they receive the reward, however if they visit another port first then an error signal is given and they receive no reward that trial. The LED turns off when the mouse touches a port.
# *Performance evaluation*: Mice move on to the next phase when they are consistently getting the reward and not getting error signals at a high rate.
# - **Phase 4:**
# *Aim*: To teach mice to wait for a short time on the platform before the cue is given. Pause time = 1s.
# *Task*: This is the same as phase 3 except that mice must pause for a short time on the platform before the cue is given. This is to encourage waiting for the cue to be given so that mice don't impulsively walk off the platform before seeing where the cue is.
# *Performance evaluation*: Mice are moved on when they can consistently get the reward and are not getting errors. They should also be showing a clear pause on the platform before moving off.
# - **Phase 'test':**
# *Aim*: To examine the strategy that the mice are using to get to port 1.
# *Task*: 5 trials are given with the LED at port 1 and then 10 trials are given with the LED at port 3. IF the mice go to either port 1 or 3 they can receive reward.
# *Performance evaluation*: The aim is to evaluate if the mice are using the LED or the external landmarks in the arena to navigate to port 1. If mice switch to going to port 3 once the cue is given there, then they are following the LED. If they continue to go to port 1, then they are following the landmarks in the arena.
# - **Phase 5:**
# *Aim*: Introduction of port 3 consistently.
# *Task*: Mice are given the cue at port 3, and are allowed to make mistakes without receiving an error signal.
# *Performance evaluation*: This phase is only brief, and is moved on from when mice are showing that they can go to port 3 consistenly and aren't just checking randomly.
# - **Phase 7:**
# *Aim*: To teach mice to consistently follow the LED to get the reward.
# *Task*: The cue and correct port are switched randomly between port 1 and port 3. Mice are given error signal for incorrect port touches.
# *Performance evalutation*: Mice are moved on when they are consistenly getting the task correct and following the LED location.
# - **Phase 9:**
# *Aim*: To teach the mice that the reward is potentially given at all 6 ports.
# *Task*: Cue randomly switched between ports 1 to 6.
# - **Phase 4b:**
# *Aim*: Teaching the mice audio trials.
# *Task*: The cue is randomly switched between a visual cue at port 1 and an audio cue. Mice must go to port 1 to receive reward in both cases.
# - **Phase 4c:**
# *Aim*: Continued audio trial education.
# *Task*: Mice are only given audio trials and must go to port 1 to receive reward. Error signals are given for incorrect port touches.
# - **Phase 9b:**
# *Aim*: To teach mice a full version of the mixed cue task.
# *Task*: Visual cues are given at all ports, and audio cues are given on random trials. If the visual cue is given, micem ust go to the corresponding port, if an audio cue is given, mice must go to port 1. The proportion of audio:visual trials is set by the experimenter. I used either 1:1 or 2 parts audio 3 parts visual on sessions.
# - **Phase 9c:**
# *Aim*: To teach mice the short cue task.
# *Task*: Same are 9b but the cue time is set to only give the cue for a short time, <1sec. Visual and audio cue time are identical. Same thing about proportion as 9b, I used 1:1 audio:visual on the end day of behaviour.
#
# ### Cue time experiment:
# Mice in this cohort went through an experiment where the performance on the task was evaluated for different visual cue durations. When the cue time is short and the cue is behind the mouse, they are unable to see if and so cannot tell which port to go to. However, for my future optogenetics experiments, it is important for me to target the inhibition time to specific times in a trial, for example specifically during cue presentation or perhaps just after. I therefore performed an experiment to evaluate the radial performance of mice with different cue lengths, to find a good middle point where mice are performing movements towards cues they are seeing instantly, instead of hunting around for the cue, but without having cues so short that performance drops even for ports in front of mice.
# Cue times used: 1000ms, 500ms, 300ms, 100ms. (needs to be checked from the data as didn't note this down.)

# %% [markdown]
# ## Import modules:

# %%
# Imports:

from matplotlib import pyplot as plt
from Session_nwb import Session
from pathlib import Path
from Cohort_folder import Cohort_folder
import json
import numpy as np

cohort_directory = Path("/cephfs2/srogers/March_training")

cohort = Cohort_folder(cohort_directory, multi = True)
cohort_info = cohort.cohort
phases = cohort.phases()
# Out:
# Loading cohort info...
# Error processing 240314_131042
# Error processing 240312_125346
# Cohort info loaded

# %% [markdown]
# ## Base performance plotting:
# The aim of this plot is to show radial performance in different phases of the behaviour.
# I would like to plot the radial performance overall, in the visual trials only and in audio trials only.
# These can either be seperate plots or overlayed.
# Session groups to plot:
# - 1: Last day session full: (9c, 300ms cue with audio) - 6 mice (28th)
# - Not to plot here -- 1b: Last day 9c without audio. Since mice were getting 1:1 audio:visual, there was a chance they were just guessing when they didn't see the visual cue and not necessarily listening for the audio. I wanted to see if the mice would continue to check port 1 as much if the audio cue wasn't there, or if they would randomly pick on ones where they couldn't see.
# - 2: 16th/17th March 9b sessions - 8 mice on Sat, 6 mice on Sun, although rig broke Sun so may need to discard some.
# - 3: Individual 9c sessions in cue time experiment + phase 9 sessions on Sat 23rd. - 1 day phase 9 (23rd), 4 days with short cues (24th - 27th).
#
# Plan:
# Get all trials from sessions. Bin trials into cue presentation angle. Create 3 arrays, one of overall performance in each angle, one in visual and one in audio. Plot using radial plot function. Also plot as 2 line graphs.

# %%
# View phases dict:
phases
# Out:
# {'1': {},
#  '2': {'240314_115017': {'path': '/cephfs2/srogers/March_training/240314_114939/240314_115017_wtjx287-5c',
#    'total_trials': 38,
#    'video_length': '16m30s',
#    'mouse': 'wtjx287-5c'},
#   '240311_120415': {'path': '/cephfs2/srogers/March_training/240311_120333/240311_120415_wtjx287-5c',
#    'total_trials': 39,
#    'video_length': '27m3s',
#    'mouse': 'wtjx287-5c'},
#   '240311_125535': {'path': '/cephfs2/srogers/March_training/240311_125505/240311_125535_wtjx287-5c',
#    'total_trials': 132,
#    'video_length': '36m38s',
#    'mouse': 'wtjx287-5c'},
#   '240314_115109': {'path': '/cephfs2/srogers/March_training/240314_114939/240314_115109_wtjx287-5b',
#    'total_trials': 42,
#    'video_length': '15m38s',
#    'mouse': 'wtjx287-5b'},
#   '240311_120506': {'path': '/cephfs2/srogers/March_training/240311_120333/240311_120506_wtjx287-5b',
#    'total_trials': 39,
#    'video_length': '26m11s',
#    'mouse': 'wtjx287-5b'},
#   '240311_125721': {'path': '/cephfs2/srogers/March_training/240311_125505/240311_125721_wtjx287-5b',
#    'total_trials': 116,
#    'video_length': '34m52s',
#    'mouse': 'wtjx287-5b'},
#   '240315_130222': {'path': '/cephfs2/srogers/March_training/240315_130150/240315_130222_wtjx287-5b',
#    'total_trials': 29,
#    'video_length': '5m41s',
#    'mouse': 'wtjx287-5b'},
#   '240312_165813': {'path': '/cephfs2/srogers/March_training/240312_165722/240312_165813_wtjx298-2b',
#    'total_trials': 56,
#    'video_length': '12m55s',
#    'mouse': 'wtjx298-2b'},
#   '240311_183224': {'path': '/cephfs2/srogers/March_training/240311_182810/240311_183224_wtjx298-2b',
#    'total_trials': 149,
#    'video_length': '55m2s',
#    'mouse': 'wtjx298-2b'},
#   '240312_165917': {'path': '/cephfs2/srogers/March_training/240312_165722/240312_165917_wtjx299-4a',
#    'total_trials': 39,
#    'video_length': '11m54s',
#    'mouse': 'wtjx299-4a'},
#   '240311_183300': {'path': '/cephfs2/srogers/March_training/240311_182810/240311_183300_wtjx299-4a',
#    'total_trials': 149,
#    'video_length': '54m33s',
#    'mouse': 'wtjx299-4a'},
#   '240311_163721': {'path': '/cephfs2/srogers/March_training/240311_163644/240311_163721_wtjx287-5d',
#    'total_trials': 90,
#    'video_length': '24m2s',
#    'mouse': 'wtjx287-5d'},
#   '240311_153022': {'path': '/cephfs2/srogers/March_training/240311_152944/240311_153022_wtjx287-5d',
#    'total_trials': 3,
#    'video_length': '19m2s',
#    'mouse': 'wtjx287-5d'},
#   '240311_155927': {'path': '/cephfs2/srogers/March_training/240311_155842/240311_155927_wtjx287-5d',
#    'total_trials': 87,
#    'video_length': '24m20s',
#    'mouse': 'wtjx287-5d'},
#   '240312_140711': {'path': '/cephfs2/srogers/March_training/240312_140631/240312_140711_wtjx287-5d',
#    'total_trials': 46,
#    'video_length': '8m9s',
#    'mouse': 'wtjx287-5d'},
#   '240311_163756': {'path': '/cephfs2/srogers/March_training/240311_163644/240311_163756_wtjx306-1a',
#    'total_trials': 147,
#    'video_length': '23m28s',
#    'mouse': 'wtjx306-1a'},
#   '240311_153115': {'path': '/cephfs2/srogers/March_training/240311_152944/240311_153115_wtjx306-1a',
#    'total_trials': 16,
#    'video_length': '18m12s',
#    'mouse': 'wtjx306-1a'},
#   '240311_160019': {'path': '/cephfs2/srogers/March_training/240311_155842/240311_160019_wtjx306-1a',
#    'total_trials': 87,
#    'video_length': '23m26s',
#    'mouse': 'wtjx306-1a'},
#   '240312_140829': {'path': '/cephfs2/srogers/March_training/240312_140631/240312_140829_wtjx306-1a',
#    'total_trials': 34,
#    'video_length': '6m50s',
#    'mouse': 'wtjx306-1a'},
#   '240312_154945': {'path': '/cephfs2/srogers/March_training/240312_154730/240312_154945_wtjx306-1b',
#    'total_trials': 75,
#    'video_length': '14m34s',
#    'mouse': 'wtjx306-1b'},
#   '240311_171519': {'path': '/cephfs2/srogers/March_training/240311_171424/240311_171519_wtjx306-1b',
#    'total_trials': 83,
#    'video_length': '48m24s',
#    'mouse': 'wtjx306-1b'},
#   '240312_155110': {'path': '/cephfs2/srogers/March_training/240312_154730/240312_155110_wtjx298-2a',
#    'total_trials': 89,
#    'video_length': '13m10s',
#    'mouse': 'wtjx298-2a'},
#   '240311_171646': {'path': '/cephfs2/srogers/March_training/240311_171424/240311_171646_wtjx298-2a',
#    'total_trials': 166,
#    'video_length': '47m2s',
#    'mouse': 'wtjx298-2a'}},
#  '3': {'240314_120807': {'path': '/cephfs2/srogers/March_training/240314_120720/240314_120807_wtjx287-5c',
#    'total_trials': 79,
#    'video_length': '12m31s',
#    'mouse': 'wtjx287-5c'},
#   '240312_123906': {'path': '/cephfs2/srogers/March_training/240312_123141/240312_123906_wtjx287-5c',
#    'total_trials': 48,
#    'video_length': '8m38s',
#    'mouse': 'wtjx287-5c'},
#   '240314_120852': {'path': '/cephfs2/srogers/March_training/240314_120720/240314_120852_wtjx287-5b',
#    'total_trials': 38,
#    'video_length': '11m45s',
#    'mouse': 'wtjx287-5b'},
#   '240312_124105': {'path': '/cephfs2/srogers/March_training/240312_123141/240312_124105_wtjx287-5b',
#    'total_trials': 6,
#    'video_length': '6m37s',
#    'mouse': 'wtjx287-5b'},
#   '240312_171744': {'path': '/cephfs2/srogers/March_training/240312_171150/240312_171744_wtjx298-2b',
#    'total_trials': 142,
#    'video_length': '31m21s',
#    'mouse': 'wtjx298-2b'},
#   '240312_171908': {'path': '/cephfs2/srogers/March_training/240312_171150/240312_171908_wtjx299-4a',
#    'total_trials': 109,
#    'video_length': '29m50s',
#    'mouse': 'wtjx299-4a'},
#   '240312_141755': {'path': '/cephfs2/srogers/March_training/240312_141706/240312_141755_wtjx287-5d',
#    'total_trials': 76,
#    'video_length': '19m16s',
#    'mouse': 'wtjx287-5d'},
#   '240314_140231': {'path': '/cephfs2/srogers/March_training/240314_140151/240314_140231_wtjx287-5d',
#    'total_trials': 53,
#    'video_length': '7m2s',
#    'mouse': 'wtjx287-5d'},
#   '240312_141845': {'path': '/cephfs2/srogers/March_training/240312_141706/240312_141845_wtjx306-1a',
#    'total_trials': 82,
#    'video_length': '18m25s',
#    'mouse': 'wtjx306-1a'},
#   '240314_140315': {'path': '/cephfs2/srogers/March_training/240314_140151/240314_140315_wtjx306-1a',
#    'total_trials': 32,
#    'video_length': '6m18s',
#    'mouse': 'wtjx306-1a'},
#   '240312_160810': {'path': '/cephfs2/srogers/March_training/240312_160455/240312_160810_wtjx306-1b',
#    'total_trials': 117,
#    'video_length': '23m19s',
#    'mouse': 'wtjx306-1b'},
#   '240313_155828': {'path': '/cephfs2/srogers/March_training/240313_155124/240313_155828_wtjx306-1b',
#    'total_trials': 131,
#    'video_length': '35m47s',
#    'mouse': 'wtjx306-1b'},
#   '240312_160902': {'path': '/cephfs2/srogers/March_training/240312_160455/240312_160902_wtjx298-2a',
#    'total_trials': 85,
#    'video_length': '22m25s',
#    'mouse': 'wtjx298-2a'},
#   '240313_160101': {'path': '/cephfs2/srogers/March_training/240313_155124/240313_160101_wtjx298-2a',
#    'total_trials': 26,
#    'video_length': '33m16s',
#    'mouse': 'wtjx298-2a'}},
#  '3b': {},
#  '3c': {},
#  '4': {'240314_122147': {'path': '/cephfs2/srogers/March_training/240314_122107/240314_122147_wtjx287-5c',
#    'total_trials': 58,
#    'video_length': '24m20s',
#    'mouse': 'wtjx287-5c'},
#   '240312_130055': {'path': '/cephfs2/srogers/March_training/240312_130019/240312_130055_wtjx287-5c',
#    'total_trials': 121,
#    'video_length': '39m30s',
#    'mouse': 'wtjx287-5c'},
#   '240314_122233': {'path': '/cephfs2/srogers/March_training/240314_122107/240314_122233_wtjx287-5b',
#    'total_trials': 60,
#    'video_length': '23m35s',
#    'mouse': 'wtjx287-5b'},
#   '240315_125138': {'path': '/cephfs2/srogers/March_training/240315_125104/240315_125138_wtjx287-5b',
#    'total_trials': 15,
#    'video_length': '9m56s',
#    'mouse': 'wtjx287-5b'},
#   '240312_130238': {'path': '/cephfs2/srogers/March_training/240312_130019/240312_130238_wtjx287-5b',
#    'total_trials': 34,
#    'video_length': '37m46s',
#    'mouse': 'wtjx287-5b'},
#   '240315_130850': {'path': '/cephfs2/srogers/March_training/240315_130821/240315_130850_wtjx287-5b',
#    'total_trials': 20,
#    'video_length': '8m21s',
#    'mouse': 'wtjx287-5b'},
#   '240314_175216': {'path': '/cephfs2/srogers/March_training/240314_175003/240314_175216_wtjx298-2b',
#    'total_trials': 49,
#    'video_length': '27m21s',
#    'mouse': 'wtjx298-2b'},
#   '240314_175254': {'path': '/cephfs2/srogers/March_training/240314_175003/240314_175254_wtjx299-4a',
#    'total_trials': 71,
#    'video_length': '26m42s',
#    'mouse': 'wtjx299-4a'},
#   '240312_144723': {'path': '/cephfs2/srogers/March_training/240312_144619/240312_144723_wtjx287-5d',
#    'total_trials': 168,
#    'video_length': '32m45s',
#    'mouse': 'wtjx287-5d'},
#   '240314_141104': {'path': '/cephfs2/srogers/March_training/240314_141014/240314_141104_wtjx287-5d',
#    'total_trials': 55,
#    'video_length': '21m37s',
#    'mouse': 'wtjx287-5d'},
#   '240312_144807': {'path': '/cephfs2/srogers/March_training/240312_144619/240312_144807_wtjx306-1a',
#    'total_trials': 84,
#    'video_length': '32m3s',
#    'mouse': 'wtjx306-1a'},
#   '240314_141158': {'path': '/cephfs2/srogers/March_training/240314_141014/240314_141158_wtjx306-1a',
#    'total_trials': 118,
#    'video_length': '20m43s',
#    'mouse': 'wtjx306-1a'},
#   '240313_163649': {'path': '/cephfs2/srogers/March_training/240313_163545/240313_163649_wtjx306-1b',
#    'total_trials': 101,
#    'video_length': '31m30s',
#    'mouse': 'wtjx306-1b'},
#   '240314_160747': {'path': '/cephfs2/srogers/March_training/240314_160717/240314_160747_wtjx306-1b',
#    'total_trials': 65,
#    'video_length': '9m24s',
#    'mouse': 'wtjx306-1b'},
#   '240312_163541': {'path': '/cephfs2/srogers/March_training/240312_163201/240312_163541_wtjx306-1b',
#    'total_trials': 31,
#    'video_length': '9m53s',
#    'mouse': 'wtjx306-1b'},
#   '240313_163731': {'path': '/cephfs2/srogers/March_training/240313_163545/240313_163731_wtjx298-2a',
#    'total_trials': 96,
#    'video_length': '30m47s',
#    'mouse': 'wtjx298-2a'},
#   '240314_160834': {'path': '/cephfs2/srogers/March_training/240314_160717/240314_160834_wtjx298-2a',
#    'total_trials': 44,
#    'video_length': '8m36s',
#    'mouse': 'wtjx298-2a'},
#   '240312_163612': {'path': '/cephfs2/srogers/March_training/240312_163201/240312_163612_wtjx298-2a',
#    'total_trials': 23,
#    'video_length': '9m24s',
#    'mouse': 'wtjx298-2a'}},
#  '4b': {'240328_135617': {'path': '/cephfs2/srogers/March_training/240328_135537/240328_135617_wtjx287-5c',
#    'total_trials': 75,
#    'video_length': '12m49s',
#    'mouse': 'wtjx287-5c'},
#   '240315_134730': {'path': '/cephfs2/srogers/March_training/240315_134320/240315_134730_wtjx287-5c',
#    'total_trials': 96,
#    'video_length': '16m10s',
#    'mouse': 'wtjx287-5c'},
#   '240328_135653': {'path': '/cephfs2/srogers/March_training/240328_135537/240328_135653_wtjx287-5b',
#    'total_trials': 87,
#    'video_length': '12m21s',
#    'mouse': 'wtjx287-5b'},
#   '240315_195427': {'path': '/cephfs2/srogers/March_training/240315_195349/240315_195427_wtjx287-5b',
#    'total_trials': 118,
#    'video_length': '22m21s',
#    'mouse': 'wtjx287-5b'},
#   '240315_171403': {'path': '/cephfs2/srogers/March_training/240315_171302/240315_171403_wtjx298-2b',
#    'total_trials': 87,
#    'video_length': '19m15s',
#    'mouse': 'wtjx298-2b'},
#   '240316_192503': {'path': '/cephfs2/srogers/March_training/240316_192425/240316_192503_wtjx298-2b',
#    'total_trials': 107,
#    'video_length': '19m22s',
#    'mouse': 'wtjx298-2b'},
#   '240316_192739': {'path': '/cephfs2/srogers/March_training/240316_192425/240316_192739_wtjx299-4a',
#    'total_trials': 107,
#    'video_length': '16m48s',
#    'mouse': 'wtjx299-4a'},
#   '240315_195500': {'path': '/cephfs2/srogers/March_training/240315_195349/240315_195500_wtjx299-4a',
#    'total_trials': 159,
#    'video_length': '21m47s',
#    'mouse': 'wtjx299-4a'},
#   '240315_134359': {'path': '/cephfs2/srogers/March_training/240315_134320/240315_134359_wtjx287-5d',
#    'total_trials': 98,
#    'video_length': '19m41s',
#    'mouse': 'wtjx287-5d'},
#   '240315_152950': {'path': '/cephfs2/srogers/March_training/240315_152919/240315_152950_wtjx306-1a',
#    'total_trials': 125,
#    'video_length': '21m5s',
#    'mouse': 'wtjx306-1a'},
#   '240316_180111': {'path': '/cephfs2/srogers/March_training/240316_180026/240316_180111_wtjx306-1b',
#    'total_trials': 80,
#    'video_length': '15m46s',
#    'mouse': 'wtjx306-1b'},
#   '240315_153037': {'path': '/cephfs2/srogers/March_training/240315_152919/240315_153037_wtjx306-1b',
#    'total_trials': 123,
#    'video_length': '20m11s',
#    'mouse': 'wtjx306-1b'},
#   '240315_171336': {'path': '/cephfs2/srogers/March_training/240315_171302/240315_171336_wtjx298-2a',
#    'total_trials': 123,
#    'video_length': '19m42s',
#    'mouse': 'wtjx298-2a'},
#   '240316_180212': {'path': '/cephfs2/srogers/March_training/240316_180026/240316_180212_wtjx298-2a',
#    'total_trials': 74,
#    'video_length': '14m46s',
#    'mouse': 'wtjx298-2a'}},
#  '4c': {'240328_141128': {'path': '/cephfs2/srogers/March_training/240328_141056/240328_141128_wtjx287-5c',
#    'total_trials': 114,
#    'video_length': '17m54s',
#    'mouse': 'wtjx287-5c'},
#   '240328_141200': {'path': '/cephfs2/srogers/March_training/240328_141056/240328_141200_wtjx287-5b',
#    'total_trials': 112,
#    'video_length': '17m25s',
#    'mouse': 'wtjx287-5b'},
#   '240328_153404': {'path': '/cephfs2/srogers/March_training/240328_153153/240328_153404_wtjx287-5d',
#    'total_trials': 79,
#    'video_length': '14m18s',
#    'mouse': 'wtjx287-5d'},
#   '240328_153432': {'path': '/cephfs2/srogers/March_training/240328_153153/240328_153432_wtjx306-1a',
#    'total_trials': 89,
#    'video_length': '13m48s',
#    'mouse': 'wtjx306-1a'},
#   '240328_170313': {'path': '/cephfs2/srogers/March_training/240328_170248/240328_170313_wtjx306-1b',
#    'total_trials': 13,
#    'video_length': '16m42s',
#    'mouse': 'wtjx306-1b'},
#   '240328_172102': {'path': '/cephfs2/srogers/March_training/240328_172037/240328_172102_wtjx306-1b',
#    'total_trials': 96,
#    'video_length': '24m10s',
#    'mouse': 'wtjx306-1b'},
#   '240328_170352': {'path': '/cephfs2/srogers/March_training/240328_170248/240328_170352_wtjx298-2a',
#    'total_trials': 118,
#    'video_length': '16m17s',
#    'mouse': 'wtjx298-2a'}},
#  'test': {'240314_124741': {'path': '/cephfs2/srogers/March_training/240314_124651/240314_124741_wtjx287-5c',
#    'total_trials': 15,
#    'video_length': '6m3s',
#    'mouse': 'wtjx287-5c'},
#   '240314_124833': {'path': '/cephfs2/srogers/March_training/240314_124651/240314_124833_wtjx287-5b',
#    'total_trials': 15,
#    'video_length': '5m10s',
#    'mouse': 'wtjx287-5b'},
#   '240314_182239': {'path': '/cephfs2/srogers/March_training/240314_182152/240314_182239_wtjx298-2b',
#    'total_trials': 15,
#    'video_length': '4m46s',
#    'mouse': 'wtjx298-2b'},
#   '240314_182330': {'path': '/cephfs2/srogers/March_training/240314_182152/240314_182330_wtjx299-4a',
#    'total_trials': 15,
#    'video_length': '3m55s',
#    'mouse': 'wtjx299-4a'},
#   '240314_143404': {'path': '/cephfs2/srogers/March_training/240314_143333/240314_143404_wtjx287-5d',
#    'total_trials': 15,
#    'video_length': '6m15s',
#    'mouse': 'wtjx287-5d'},
#   '240314_143447': {'path': '/cephfs2/srogers/March_training/240314_143333/240314_143447_wtjx306-1a',
#    'total_trials': 15,
#    'video_length': '5m30s',
#    'mouse': 'wtjx306-1a'},
#   '240314_161817': {'path': '/cephfs2/srogers/March_training/240314_161741/240314_161817_wtjx306-1b',
#    'total_trials': 15,
#    'video_length': '4m53s',
#    'mouse': 'wtjx306-1b'},
#   '240313_171031': {'path': '/cephfs2/srogers/March_training/240313_170922/240313_171031_wtjx306-1b',
#    'total_trials': 15,
#    'video_length': '6m52s',
#    'mouse': 'wtjx306-1b'},
#   '240314_161907': {'path': '/cephfs2/srogers/March_training/240314_161741/240314_161907_wtjx298-2a',
#    'total_trials': 15,
#    'video_length': '4m3s',
#    'mouse': 'wtjx298-2a'},
#   '240313_171139': {'path': '/cephfs2/srogers/March_training/240313_170922/240313_171139_wtjx298-2a',
#    'total_trials': 15,
#    'video_length': '5m44s',
#    'mouse': 'wtjx298-2a'}},
#  '5': {'240314_125621': {'path': '/cephfs2/srogers/March_training/240314_125427/240314_125621_wtjx287-5c',
#    'total_trials': 51,
#    'video_length': '8m59s',
#    'mouse': 'wtjx287-5c'},
#   '240314_125727': {'path': '/cephfs2/srogers/March_training/240314_125427/240314_125727_wtjx287-5b',
#    'total_trials': 23,
#    'video_length': '7m52s',
#    'mouse': 'wtjx287-5b'},
#   '240314_182936': {'path': '/cephfs2/srogers/March_training/240314_182832/240314_182936_wtjx298-2b',
#    'total_trials': 24,
#    'video_length': '7m10s',
#    'mouse': 'wtjx298-2b'},
#   '240314_183020': {'path': '/cephfs2/srogers/March_training/240314_182832/240314_183020_wtjx299-4a',
#    'total_trials': 43,
#    'video_length': '6m25s',
#    'mouse': 'wtjx299-4a'},
#   '240314_144155': {'path': '/cephfs2/srogers/March_training/240314_144112/240314_144155_wtjx287-5d',
#    'total_trials': 48,
#    'video_length': '8m43s',
#    'mouse': 'wtjx287-5d'},
#   '240314_144256': {'path': '/cephfs2/srogers/March_training/240314_144112/240314_144256_wtjx306-1a',
#    'total_trials': 34,
#    'video_length': '7m43s',
#    'mouse': 'wtjx306-1a'},
#   '240314_164354': {'path': '/cephfs2/srogers/March_training/240314_164016/240314_164354_wtjx306-1b',
#    'total_trials': 24,
#    'video_length': '3m41s',
#    'mouse': 'wtjx306-1b'},
#   '240314_164419': {'path': '/cephfs2/srogers/March_training/240314_164016/240314_164419_wtjx298-2a',
#    'total_trials': 20,
#    'video_length': '3m16s',
#    'mouse': 'wtjx298-2a'}},
#  '6': {},
#  '7': {'240314_131231': {'path': '/cephfs2/srogers/March_training/240314_131157/240314_131231_wtjx287-5c',
#    'total_trials': 124,
#    'video_length': '23m51s',
#    'mouse': 'wtjx287-5c'},
#   '240314_130942': {'path': '/cephfs2/srogers/March_training/240314_130900/240314_130942_wtjx287-5c',
#    'total_trials': 7,
#    'video_length': '1m57s',
#    'mouse': 'wtjx287-5c'},
#   '240314_131313': {'path': '/cephfs2/srogers/March_training/240314_131157/240314_131313_wtjx287-5b',
#    'total_trials': 32,
#    'video_length': '23m9s',
#    'mouse': 'wtjx287-5b'},
#   '240314_183756': {'path': '/cephfs2/srogers/March_training/240314_183720/240314_183756_wtjx298-2b',
#    'total_trials': 279,
#    'video_length': '50m59s',
#    'mouse': 'wtjx298-2b'},
#   '240314_183835': {'path': '/cephfs2/srogers/March_training/240314_183720/240314_183835_wtjx299-4a',
#    'total_trials': 307,
#    'video_length': '50m13s',
#    'mouse': 'wtjx299-4a'},
#   '240314_145143': {'path': '/cephfs2/srogers/March_training/240314_145101/240314_145143_wtjx287-5d',
#    'total_trials': 254,
#    'video_length': '53m1s',
#    'mouse': 'wtjx287-5d'},
#   '240314_145234': {'path': '/cephfs2/srogers/March_training/240314_145101/240314_145234_wtjx306-1a',
#    'total_trials': 313,
#    'video_length': '52m10s',
#    'mouse': 'wtjx306-1a'},
#   '240314_164825': {'path': '/cephfs2/srogers/March_training/240314_164756/240314_164825_wtjx306-1b',
#    'total_trials': 276,
#    'video_length': '45m16s',
#    'mouse': 'wtjx306-1b'},
#   '240314_164854': {'path': '/cephfs2/srogers/March_training/240314_164756/240314_164854_wtjx298-2a',
#    'total_trials': 335,
#    'video_length': '44m46s',
#    'mouse': 'wtjx298-2a'}},
#  '8': {},
#  '9': {'240323_130517': {'path': '/cephfs2/srogers/March_training/240323_130245/240323_130517_wtjx287-5c',
#    'total_trials': 446,
#    'video_length': '57m57s',
#    'mouse': 'wtjx287-5c'},
#   '240315_123714': {'path': '/cephfs2/srogers/March_training/240315_123444/240315_123714_wtjx287-5c',
#    'total_trials': 85,
#    'video_length': '12m49s',
#    'mouse': 'wtjx287-5c'},
#   '240315_133836': {'path': '/cephfs2/srogers/March_training/240315_133637/240315_133836_wtjx287-5c',
#    'total_trials': 25,
#    'video_length': '3m13s',
#    'mouse': 'wtjx287-5c'},
#   '240323_130553': {'path': '/cephfs2/srogers/March_training/240323_130245/240323_130553_wtjx287-5b',
#    'total_trials': 320,
#    'video_length': '57m24s',
#    'mouse': 'wtjx287-5b'},
#   '240315_123619': {'path': '/cephfs2/srogers/March_training/240315_123444/240315_123619_wtjx287-5b',
#    'total_trials': 16,
#    'video_length': '13m41s',
#    'mouse': 'wtjx287-5b'},
#   '240315_190658': {'path': '/cephfs2/srogers/March_training/240315_190615/240315_190658_wtjx287-5b',
#    'total_trials': 196,
#    'video_length': '46m20s',
#    'mouse': 'wtjx287-5b'},
#   '240323_164315': {'path': '/cephfs2/srogers/March_training/240323_164113/240323_164315_wtjx298-2b',
#    'total_trials': 446,
#    'video_length': '65m35s',
#    'mouse': 'wtjx298-2b'},
#   '240315_170621': {'path': '/cephfs2/srogers/March_training/240315_165940/240315_170621_wtjx298-2b',
#    'total_trials': 38,
#    'video_length': '6m22s',
#    'mouse': 'wtjx298-2b'},
#   '240323_164337': {'path': '/cephfs2/srogers/March_training/240323_164113/240323_164337_wtjx299-4a',
#    'total_trials': 474,
#    'video_length': '65m14s',
#    'mouse': 'wtjx299-4a'},
#   '240315_190731': {'path': '/cephfs2/srogers/March_training/240315_190615/240315_190731_wtjx299-4a',
#    'total_trials': 192,
#    'video_length': '45m47s',
#    'mouse': 'wtjx299-4a'},
#   '240315_132132': {'path': '/cephfs2/srogers/March_training/240315_132046/240315_132132_wtjx287-5d',
#    'total_trials': 87,
#    'video_length': '14m22s',
#    'mouse': 'wtjx287-5d'},
#   '240323_141433': {'path': '/cephfs2/srogers/March_training/240323_141359/240323_141433_wtjx287-5d',
#    'total_trials': 408,
#    'video_length': '64m0s',
#    'mouse': 'wtjx287-5d'},
#   '240315_133721': {'path': '/cephfs2/srogers/March_training/240315_133637/240315_133721_wtjx287-5d',
#    'total_trials': 20,
#    'video_length': '4m29s',
#    'mouse': 'wtjx287-5d'},
#   '240315_151240': {'path': '/cephfs2/srogers/March_training/240315_151037/240315_151240_wtjx306-1a',
#    'total_trials': 85,
#    'video_length': '15m46s',
#    'mouse': 'wtjx306-1a'},
#   '240323_141510': {'path': '/cephfs2/srogers/March_training/240323_141359/240323_141510_wtjx306-1a',
#    'total_trials': 343,
#    'video_length': '63m20s',
#    'mouse': 'wtjx306-1a'},
#   '240315_151327': {'path': '/cephfs2/srogers/March_training/240315_151037/240315_151327_wtjx306-1b',
#    'total_trials': 75,
#    'video_length': '14m59s',
#    'mouse': 'wtjx306-1b'},
#   '240323_152751': {'path': '/cephfs2/srogers/March_training/240323_152542/240323_152751_wtjx306-1b',
#    'total_trials': 474,
#    'video_length': '59m28s',
#    'mouse': 'wtjx306-1b'},
#   '240315_170344': {'path': '/cephfs2/srogers/March_training/240315_165940/240315_170344_wtjx298-2a',
#    'total_trials': 39,
#    'video_length': '9m0s',
#    'mouse': 'wtjx298-2a'},
#   '240323_152825': {'path': '/cephfs2/srogers/March_training/240323_152542/240323_152825_wtjx298-2a',
#    'total_trials': 361,
#    'video_length': '58m50s',
#    'mouse': 'wtjx298-2a'}},
#  '9b': {'240317_131559': {'path': '/cephfs2/srogers/March_training/240317_131441/240317_131559_wtjx287-5c',
#    'total_trials': 302,
#    'video_length': '56m8s',
#    'mouse': 'wtjx287-5c'},
#   '240316_154401': {'path': '/cephfs2/srogers/March_training/240316_153555/240316_154401_wtjx287-5c',
#    'total_trials': 310,
#    'video_length': '45m25s',
#    'mouse': 'wtjx287-5c'},
#   '240317_131515': {'path': '/cephfs2/srogers/March_training/240317_131441/240317_131515_wtjx287-5b',
#    'total_trials': 357,
#    'video_length': '56m49s',
#    'mouse': 'wtjx287-5b'},
#   '240316_154327': {'path': '/cephfs2/srogers/March_training/240316_153555/240316_154327_wtjx287-5b',
#    'total_trials': 219,
#    'video_length': '46m2s',
#    'mouse': 'wtjx287-5b'},
#   '240315_141434': {'path': '/cephfs2/srogers/March_training/240315_141317/240315_141434_wtjx287-5b',
#    'total_trials': 287,
#    'video_length': '38m21s',
#    'mouse': 'wtjx287-5b'},
#   '240315_141127': {'path': '/cephfs2/srogers/March_training/240315_141003-e/240315_141127_wtjx287-5b',
#    'total_trials': 7,
#    'video_length': '1m33s',
#    'mouse': 'wtjx287-5b'},
#   '240316_194551': {'path': '/cephfs2/srogers/March_training/240316_194513/240316_194551_wtjx298-2b',
#    'total_trials': 190,
#    'video_length': '38m2s',
#    'mouse': 'wtjx298-2b'},
#   '240315_175716': {'path': '/cephfs2/srogers/March_training/240315_175609/240315_175716_wtjx298-2b',
#    'total_trials': 289,
#    'video_length': '53m38s',
#    'mouse': 'wtjx298-2b'},
#   '240315_173912': {'path': '/cephfs2/srogers/March_training/240315_173734/240315_173912_wtjx298-2b',
#    'total_trials': 29,
#    'video_length': '5m14s',
#    'mouse': 'wtjx298-2b'},
#   '240316_194622': {'path': '/cephfs2/srogers/March_training/240316_194513/240316_194622_wtjx299-4a',
#    'total_trials': 159,
#    'video_length': '37m30s',
#    'mouse': 'wtjx299-4a'},
#   '240316_164020': {'path': '/cephfs2/srogers/March_training/240316_163809/240316_164020_wtjx287-5d',
#    'total_trials': 354,
#    'video_length': '69m16s',
#    'mouse': 'wtjx287-5d'},
#   '240317_142339': {'path': '/cephfs2/srogers/March_training/240317_142217/240317_142339_wtjx287-5d',
#    'total_trials': 311,
#    'video_length': '47m22s',
#    'mouse': 'wtjx287-5d'},
#   '240315_141356': {'path': '/cephfs2/srogers/March_training/240315_141317/240315_141356_wtjx287-5d',
#    'total_trials': 235,
#    'video_length': '39m2s',
#    'mouse': 'wtjx287-5d'},
#   '240315_141031': {'path': '/cephfs2/srogers/March_training/240315_141003-e/240315_141031_wtjx287-5d',
#    'total_trials': 8,
#    'video_length': '2m29s',
#    'mouse': 'wtjx287-5d'},
#   '240316_164109': {'path': '/cephfs2/srogers/March_training/240316_163809/240316_164109_wtjx306-1a',
#    'total_trials': 424,
#    'video_length': '68m27s',
#    'mouse': 'wtjx306-1a'},
#   '240317_142411': {'path': '/cephfs2/srogers/March_training/240317_142217/240317_142411_wtjx306-1a',
#    'total_trials': 237,
#    'video_length': '46m49s',
#    'mouse': 'wtjx306-1a'},
#   '240315_155356': {'path': '/cephfs2/srogers/March_training/240315_155321/240315_155356_wtjx306-1a',
#    'total_trials': 359,
#    'video_length': '59m6s',
#    'mouse': 'wtjx306-1a'},
#   '240317_153913': {'path': '/cephfs2/srogers/March_training/240317_153832/240317_153913_wtjx306-1b',
#    'total_trials': 118,
#    'video_length': '23m1s',
#    'mouse': 'wtjx306-1b'},
#   '240315_155442': {'path': '/cephfs2/srogers/March_training/240315_155321/240315_155442_wtjx306-1b',
#    'total_trials': 248,
#    'video_length': '58m20s',
#    'mouse': 'wtjx306-1b'},
#   '240316_181828': {'path': '/cephfs2/srogers/March_training/240316_181800/240316_181828_wtjx306-1b',
#    'total_trials': 260,
#    'video_length': '54m16s',
#    'mouse': 'wtjx306-1b'},
#   '240317_153949': {'path': '/cephfs2/srogers/March_training/240317_153832/240317_153949_wtjx298-2a',
#    'total_trials': 85,
#    'video_length': '22m26s',
#    'mouse': 'wtjx298-2a'},
#   '240315_175643': {'path': '/cephfs2/srogers/March_training/240315_175609/240315_175643_wtjx298-2a',
#    'total_trials': 385,
#    'video_length': '54m9s',
#    'mouse': 'wtjx298-2a'},
#   '240315_173836': {'path': '/cephfs2/srogers/March_training/240315_173734/240315_173836_wtjx298-2a',
#    'total_trials': 0,
#    'video_length': '5m46s',
#    'mouse': 'wtjx298-2a'},
#   '240316_181904': {'path': '/cephfs2/srogers/March_training/240316_181800/240316_181904_wtjx298-2a',
#    'total_trials': 350,
#    'video_length': '53m44s',
#    'mouse': 'wtjx298-2a'}},
#  '9c': {'240327_121146': {'path': '/cephfs2/srogers/March_training/240327_121111/240327_121146_wtjx287-5c',
#    'total_trials': 293,
#    'video_length': '60m33s',
#    'mouse': 'wtjx287-5c'},
#   '240328_143915': {'path': '/cephfs2/srogers/March_training/240328_143854/240328_143915_wtjx287-5c',
#    'total_trials': 216,
#    'video_length': '35m21s',
#    'mouse': 'wtjx287-5c'},
#   '240328_143110': {'path': '/cephfs2/srogers/March_training/240328_141056/240328_143110_wtjx287-5c',
#    'total_trials': 20,
#    'video_length': '7m3s',
#    'mouse': 'wtjx287-5c'},
#   '240325_150047': {'path': '/cephfs2/srogers/March_training/240325_145822/240325_150047_wtjx287-5c',
#    'total_trials': 364,
#    'video_length': '57m53s',
#    'mouse': 'wtjx287-5c'},
#   '240324_125635': {'path': '/cephfs2/srogers/March_training/240324_125559/240324_125635_wtjx287-5c',
#    'total_trials': 446,
#    'video_length': '61m2s',
#    'mouse': 'wtjx287-5c'},
#   '240326_140814': {'path': '/cephfs2/srogers/March_training/240326_140616/240326_140814_wtjx287-5c',
#    'total_trials': 358,
#    'video_length': '59m0s',
#    'mouse': 'wtjx287-5c'},
#   '240327_121504': {'path': '/cephfs2/srogers/March_training/240327_121111/240327_121504_wtjx287-5b',
#    'total_trials': 297,
#    'video_length': '57m21s',
#    'mouse': 'wtjx287-5b'},
#   '240328_143947': {'path': '/cephfs2/srogers/March_training/240328_143854/240328_143947_wtjx287-5b',
#    'total_trials': 189,
#    'video_length': '34m50s',
#    'mouse': 'wtjx287-5b'},
#   '240328_143231': {'path': '/cephfs2/srogers/March_training/240328_141056/240328_143231_wtjx287-5b',
#    'total_trials': 23,
#    'video_length': '5m41s',
#    'mouse': 'wtjx287-5b'},
#   '240325_150001': {'path': '/cephfs2/srogers/March_training/240325_145822/240325_150001_wtjx287-5b',
#    'total_trials': 359,
#    'video_length': '58m35s',
#    'mouse': 'wtjx287-5b'},
#   '240324_125715': {'path': '/cephfs2/srogers/March_training/240324_125559/240324_125715_wtjx287-5b',
#    'total_trials': 373,
#    'video_length': '60m26s',
#    'mouse': 'wtjx287-5b'},
#   '240326_140923': {'path': '/cephfs2/srogers/March_training/240326_140616/240326_140923_wtjx287-5b',
#    'total_trials': 346,
#    'video_length': '57m58s',
#    'mouse': 'wtjx287-5b'},
#   '240326_174606': {'path': '/cephfs2/srogers/March_training/240326_174336/240326_174606_wtjx298-2b',
#    'total_trials': 385,
#    'video_length': '61m3s',
#    'mouse': 'wtjx298-2b'},
#   '240325_183546': {'path': '/cephfs2/srogers/March_training/240325_182553/240325_183546_wtjx298-2b',
#    'total_trials': 239,
#    'video_length': '40m2s',
#    'mouse': 'wtjx298-2b'},
#   '240324_163540': {'path': '/cephfs2/srogers/March_training/240324_163507/240324_163540_wtjx298-2b',
#    'total_trials': 421,
#    'video_length': '62m9s',
#    'mouse': 'wtjx298-2b'},
#   '240327_160142': {'path': '/cephfs2/srogers/March_training/240327_160116/240327_160142_wtjx298-2b',
#    'total_trials': 315,
#    'video_length': '53m9s',
#    'mouse': 'wtjx298-2b'},
#   '240326_174407': {'path': '/cephfs2/srogers/March_training/240326_174336/240326_174407_wtjx299-4a',
#    'total_trials': 147,
#    'video_length': '63m5s',
#    'mouse': 'wtjx299-4a'},
#   '240325_183459': {'path': '/cephfs2/srogers/March_training/240325_182553/240325_183459_wtjx299-4a',
#    'total_trials': 234,
#    'video_length': '40m45s',
#    'mouse': 'wtjx299-4a'},
#   '240324_163617': {'path': '/cephfs2/srogers/March_training/240324_163507/240324_163617_wtjx299-4a',
#    'total_trials': 558,
#    'video_length': '61m28s',
#    'mouse': 'wtjx299-4a'},
#   '240327_160220': {'path': '/cephfs2/srogers/March_training/240327_160116/240327_160220_wtjx299-4a',
#    'total_trials': 299,
#    'video_length': '52m31s',
#    'mouse': 'wtjx299-4a'},
#   '240327_132449': {'path': '/cephfs2/srogers/March_training/240327_132415/240327_132449_wtjx287-5d',
#    'total_trials': 295,
#    'video_length': '60m53s',
#    'mouse': 'wtjx287-5d'},
#   '240328_163535': {'path': '/cephfs2/srogers/March_training/240328_163129/240328_163535_wtjx287-5d',
#    'total_trials': 76,
#    'video_length': '18m3s',
#    'mouse': 'wtjx287-5d'},
#   '240325_161055': {'path': '/cephfs2/srogers/March_training/240325_161028/240325_161055_wtjx287-5d',
#    'total_trials': 304,
#    'video_length': '60m1s',
#    'mouse': 'wtjx287-5d'},
#   '240324_141200': {'path': '/cephfs2/srogers/March_training/240324_141114/240324_141200_wtjx287-5d',
#    'total_trials': 368,
#    'video_length': '59m18s',
#    'mouse': 'wtjx287-5d'},
#   '240326_151736': {'path': '/cephfs2/srogers/March_training/240326_151654/240326_151736_wtjx287-5d',
#    'total_trials': 317,
#    'video_length': '56m54s',
#    'mouse': 'wtjx287-5d'},
#   '240328_155006': {'path': '/cephfs2/srogers/March_training/240328_154928/240328_155006_wtjx287-5d',
#    'total_trials': 200,
#    'video_length': '38m39s',
#    'mouse': 'wtjx287-5d'},
#   '240327_132521': {'path': '/cephfs2/srogers/March_training/240327_132415/240327_132521_wtjx306-1a',
#    'total_trials': 417,
#    'video_length': '60m22s',
#    'mouse': 'wtjx306-1a'},
#   '240328_163559': {'path': '/cephfs2/srogers/March_training/240328_163129/240328_163559_wtjx306-1a',
#    'total_trials': 106,
#    'video_length': '17m38s',
#    'mouse': 'wtjx306-1a'},
#   '240325_161132': {'path': '/cephfs2/srogers/March_training/240325_161028/240325_161132_wtjx306-1a',
#    'total_trials': 409,
#    'video_length': '59m23s',
#    'mouse': 'wtjx306-1a'},
#   '240324_141337': {'path': '/cephfs2/srogers/March_training/240324_141114/240324_141337_wtjx306-1a',
#    'total_trials': 403,
#    'video_length': '57m46s',
#    'mouse': 'wtjx306-1a'},
#   '240326_151928': {'path': '/cephfs2/srogers/March_training/240326_151654/240326_151928_wtjx306-1a',
#    'total_trials': 381,
#    'video_length': '55m5s',
#    'mouse': 'wtjx306-1a'},
#   '240328_155038': {'path': '/cephfs2/srogers/March_training/240328_154928/240328_155038_wtjx306-1a',
#    'total_trials': 280,
#    'video_length': '37m59s',
#    'mouse': 'wtjx306-1a'},
#   '240326_162959': {'path': '/cephfs2/srogers/March_training/240326_162919/240326_162959_wtjx306-1b',
#    'total_trials': 328,
#    'video_length': '60m46s',
#    'mouse': 'wtjx306-1b'},
#   '240327_151337': {'path': '/cephfs2/srogers/March_training/240327_151310/240327_151337_wtjx306-1b',
#    'total_trials': 130,
#    'video_length': '32m14s',
#    'mouse': 'wtjx306-1b'},
#   '240324_152412': {'path': '/cephfs2/srogers/March_training/240324_152126/240324_152412_wtjx306-1b',
#    'total_trials': 423,
#    'video_length': '55m39s',
#    'mouse': 'wtjx306-1b'},
#   '240325_172254': {'path': '/cephfs2/srogers/March_training/240325_172228/240325_172254_wtjx306-1b',
#    'total_trials': 366,
#    'video_length': '57m23s',
#    'mouse': 'wtjx306-1b'},
#   '240328_182501': {'path': '/cephfs2/srogers/March_training/240328_182436/240328_182501_wtjx306-1b',
#    'total_trials': 139,
#    'video_length': '26m15s',
#    'mouse': 'wtjx306-1b'},
#   '240327_144246': {'path': '/cephfs2/srogers/March_training/240327_144209/240327_144246_wtjx306-1b',
#    'total_trials': 124,
#    'video_length': '28m42s',
#    'mouse': 'wtjx306-1b'},
#   '240328_174624': {'path': '/cephfs2/srogers/March_training/240328_174559/240328_174624_wtjx306-1b',
#    'total_trials': 218,
#    'video_length': '35m37s',
#    'mouse': 'wtjx306-1b'},
#   '240326_163043': {'path': '/cephfs2/srogers/March_training/240326_162919/240326_163043_wtjx298-2a',
#    'total_trials': 401,
#    'video_length': '60m7s',
#    'mouse': 'wtjx298-2a'},
#   '240327_151415': {'path': '/cephfs2/srogers/March_training/240327_151310/240327_151415_wtjx298-2a',
#    'total_trials': 194,
#    'video_length': '31m37s',
#    'mouse': 'wtjx298-2a'},
#   '240324_152446': {'path': '/cephfs2/srogers/March_training/240324_152126/240324_152446_wtjx298-2a',
#    'total_trials': 410,
#    'video_length': '55m1s',
#    'mouse': 'wtjx298-2a'},
#   '240325_172338': {'path': '/cephfs2/srogers/March_training/240325_172228/240325_172338_wtjx298-2a',
#    'total_trials': 442,
#    'video_length': '56m37s',
#    'mouse': 'wtjx298-2a'},
#   '240328_182532': {'path': '/cephfs2/srogers/March_training/240328_182436/240328_182532_wtjx298-2a',
#    'total_trials': 164,
#    'video_length': '25m45s',
#    'mouse': 'wtjx298-2a'},
#   '240327_144313': {'path': '/cephfs2/srogers/March_training/240327_144209/240327_144313_wtjx298-2a',
#    'total_trials': 144,
#    'video_length': '28m14s',
#    'mouse': 'wtjx298-2a'},
#   '240328_174653': {'path': '/cephfs2/srogers/March_training/240328_174559/240328_174653_wtjx298-2a',
#    'total_trials': 241,
#    'video_length': '35m5s',
#    'mouse': 'wtjx298-2a'}}}

# %%
# Group 1 session list: (Last day 9c sessions - full task)
sessions = []

for session in phases['9c']:
    date = session[:6]
    
    if date == '240328':
        sessions.append(session)
        
# sort list:
sessions.sort()

# On this day, I did one 9c with audio then one without to see their performance change, so need to filter this set.

sessions_to_exclude = [
 '240328_143110',
 '240328_143231']
    
non_audio_sessions = [
 '240328_163535',
 '240328_163559',
 '240328_182501',
 '240328_182532']

audio_9c_sessions = [
 '240328_143915',
 '240328_143947',
 '240328_155006',
 '240328_155038',
 '240328_174624',
 '240328_174653']
# Out:
# ['240328_143110',
#  '240328_143231',
#  '240328_143915',
#  '240328_143947',
#  '240328_155006',
#  '240328_155038',
#  '240328_163535',
#  '240328_163559',
#  '240328_174624',
#  '240328_174653',
#  '240328_182501',
#  '240328_182532']

# %%
# Group 2 sessions: 
# (16th/17th March 9b sessions - 8 mice on Sat, 6 mice on Sun, although rig broke Sun so may need to discard some.)

sessions = []

for session in phases['9b']:
    date = session[:6]
    
    if date == '240316' or date == '240317':
        sessions.append(session)
        
sessions.sort()

for session in sessions:
    date = session[:6]
    print(date, cohort.get_session(session, concise = True))
    
all_9b_sessions = sessions

first_day_9b = [session for session in phases['9b'] if session[:6] == '240316']
# Out:
# 240316 {'Behaviour_phase': '9b', 'total_trials': 219, 'video_length': '46m2s', 'mouse_id': 'wtjx287-5b'}
# 240316 {'Behaviour_phase': '9b', 'total_trials': 310, 'video_length': '45m25s', 'mouse_id': 'wtjx287-5c'}
# 240316 {'Behaviour_phase': '9b', 'total_trials': 354, 'video_length': '69m16s', 'mouse_id': 'wtjx287-5d'}
# 240316 {'Behaviour_phase': '9b', 'total_trials': 424, 'video_length': '68m27s', 'mouse_id': 'wtjx306-1a'}
# 240316 {'Behaviour_phase': '9b', 'total_trials': 260, 'video_length': '54m16s', 'mouse_id': 'wtjx306-1b'}
# 240316 {'Behaviour_phase': '9b', 'total_trials': 350, 'video_length': '53m44s', 'mouse_id': 'wtjx298-2a'}
# 240316 {'Behaviour_phase': '9b', 'total_trials': 190, 'video_length': '38m2s', 'mouse_id': 'wtjx298-2b'}
# 240316 {'Behaviour_phase': '9b', 'total_trials': 159, 'video_length': '37m30s', 'mouse_id': 'wtjx299-4a'}
# 240317 {'Behaviour_phase': '9b', 'total_trials': 357, 'video_length': '56m49s', 'mouse_id': 'wtjx287-5b'}
# 240317 {'Behaviour_phase': '9b', 'total_trials': 302, 'video_length': '56m8s', 'mouse_id': 'wtjx287-5c'}
# 240317 {'Behaviour_phase': '9b', 'total_trials': 311, 'video_length': '47m22s', 'mouse_id': 'wtjx287-5d'}
# 240317 {'Behaviour_phase': '9b', 'total_trials': 237, 'video_length': '46m49s', 'mouse_id': 'wtjx306-1a'}
# 240317 {'Behaviour_phase': '9b', 'total_trials': 118, 'video_length': '23m1s', 'mouse_id': 'wtjx306-1b'}
# 240317 {'Behaviour_phase': '9b', 'total_trials': 85, 'video_length': '22m26s', 'mouse_id': 'wtjx298-2a'}

# %%
# Group 3: 
# Individual 9c sessions in cue time experiment + phase 9 sessions on Sat 23rd. 
#  - 1 day phase 9 (23rd), 4 days with short cues (24th - 27th)

cue_group_unlimited = [session for session in phases['9'] if session[:6] == '240323']

cue_group_1000 = [session for session in phases['9c'] if session[:6] == '240324']

cue_group_500 = [session for session in phases['9c'] if session[:6] == '240325']

cue_group_300 = [session for session in phases['9c'] if session[:6] == '240326']

cue_group_100 = [session for session in phases['9c'] if session[:6] == '240327']

for session in cue_group_1000:
    print(session[:6], cohort.get_session(session, concise=True))
# Out:
# 240324 {'Behaviour_phase': '9c', 'total_trials': 446, 'video_length': '61m2s', 'mouse_id': 'wtjx287-5c'}
# 240324 {'Behaviour_phase': '9c', 'total_trials': 373, 'video_length': '60m26s', 'mouse_id': 'wtjx287-5b'}
# 240324 {'Behaviour_phase': '9c', 'total_trials': 421, 'video_length': '62m9s', 'mouse_id': 'wtjx298-2b'}
# 240324 {'Behaviour_phase': '9c', 'total_trials': 558, 'video_length': '61m28s', 'mouse_id': 'wtjx299-4a'}
# 240324 {'Behaviour_phase': '9c', 'total_trials': 368, 'video_length': '59m18s', 'mouse_id': 'wtjx287-5d'}
# 240324 {'Behaviour_phase': '9c', 'total_trials': 403, 'video_length': '57m46s', 'mouse_id': 'wtjx306-1a'}
# 240324 {'Behaviour_phase': '9c', 'total_trials': 423, 'video_length': '55m39s', 'mouse_id': 'wtjx306-1b'}
# 240324 {'Behaviour_phase': '9c', 'total_trials': 410, 'video_length': '55m1s', 'mouse_id': 'wtjx298-2a'}

# %%
# Cue time experiment group: 
# Individual 9c sessions in cue time experiment + phase 9 sessions on Sat 23rd. 
#  - 1 day phase 9 (23rd), 4 days with short cues (24th - 27th)
dates = ['240323', '240324', '240325', '240326', '240327']

sessions = [session for session in phases['9'] if session[:6] in dates]

sessions += [session for session in phases['9c'] if session[:6] in dates]

for session in sessions:
    date = session[:6]
    print(date, cohort.get_session(session, concise = True))

# %% [markdown]
# ### Final session 9c port 1 test. See section on 1b in 'Base performance plotting'
# Goal here is to evaluate the choices in port that mice make when they don't get a visible visual cue. I would like to establish whether there is a difference in port choice between the first and second 9c session.
# Mice are meant to learn to only go to port 1 if there is an audio cue, however it may also be the case that they just guess and default to port 1 when they don't see a cue. If this was the case, then there would be a large bias in the port that mice are touching when they touch the wrong port. This should be visible in 9c audio, but I suspect that in 9c non-audio immediately afterwards, the mice are still overly checking port 1. To evaluate this, I want to get the numbers on the number of times each port is chosen as the wrong port. I suspect that port 1 would be much higher than others. For each angle bin, for unsuccessful trials, I would also like to get the probability that port 1 is chosen. It would be interesting to see if there is a bias to port one for trials where the mouse got the cue behind him.

# %% [markdown]
# ## Plot learning:
#
# My goal here is to plot the performance over time for all phases on each day.

# %%
phase_2_sessions = [session for session in phases['2'] if session[:6] == '240311']

phase_3_sessions = [session for session in phases['3'] if session[:6] == '240312']

phase_4_sessions = [session for session in phases['4'] if session[:6] == '240313']

phase_7_exclusion = ['']
phase_7_sessions = [session for session in phases['7'] if session[:6] == '240314' and session not in phase_7_exclusion]

# %% [markdown]
# ## Phase 'test' experiment:
#
# Plot results of 'test' phase:

# %%
test_phase_sessions = [session for session in phases['test'] if session[:6] == '240314']

for session in test_phase_sessions:
    date = session[:6]
    print(date, cohort.get_session(session, concise=True))
# Out:
# 240314 {'Behaviour_phase': 'test', 'total_trials': 15, 'video_length': '6m3s', 'mouse_id': 'wtjx287-5c'}
# 240314 {'Behaviour_phase': 'test', 'total_trials': 15, 'video_length': '5m10s', 'mouse_id': 'wtjx287-5b'}
# 240314 {'Behaviour_phase': 'test', 'total_trials': 15, 'video_length': '4m46s', 'mouse_id': 'wtjx298-2b'}
# 240314 {'Behaviour_phase': 'test', 'total_trials': 15, 'video_length': '3m55s', 'mouse_id': 'wtjx299-4a'}
# 240314 {'Behaviour_phase': 'test', 'total_trials': 15, 'video_length': '6m15s', 'mouse_id': 'wtjx287-5d'}
# 240314 {'Behaviour_phase': 'test', 'total_trials': 15, 'video_length': '5m30s', 'mouse_id': 'wtjx306-1a'}
# 240314 {'Behaviour_phase': 'test', 'total_trials': 15, 'video_length': '4m53s', 'mouse_id': 'wtjx306-1b'}
# 240314 {'Behaviour_phase': 'test', 'total_trials': 15, 'video_length': '4m3s', 'mouse_id': 'wtjx298-2a'}
